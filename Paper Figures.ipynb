# %%
import numpy as np
from matplotlib.gridspec import GridSpec
import matplotlib as mpl
from matplotlib import pyplot as plt
import Analysis
import regression_cv as rcv
import FitRoutine2 as fr

# %%
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
def plotFig(data,fitbit):
    xa = fitbit
    freq = xa[0]
    amp = xa[1] 
    phasel = xa[2]
    phaser = xa[3]
    height = xa[4]
    slope = xa[5]
    posleft = min(data[0])
    posright = max(data[0]) 
    v0 = xa[11]     
    xpos = np.linspace(posleft,posright,10000)
    ytargl = height + amp*np.sin(freq*xpos + phasel) + slope*(xpos - v0)
    ytargr = height + amp*np.sin(freq*xpos + phaser) + slope*(xpos - v0)
    plt.plot(data[0],data[1])
    plt.plot(xpos,ytargl,'k',linewidth=2)
    plt.plot(xpos,ytargr,'r',linewidth=2)

# %%
def t(y_min,y_max):
    diff = y_max-y_min
    p = float(diff)*0.35
    return y_min-p,y_max+p

# %%
def init_plot(i):
    i.plot()
    plt.xlim([min(i.x),max(i.x)])
    plt.ylim([min(i.y)-0.05,max(i.y)+0.05])
    
def stitch(i,x):
    i.fits[1].plot_select('b',['k','r'],[2,2],i.fits[1].pos_left,x)
    i.fits[0].plot_select('b',['r','#00ff00'],[2,2],x,i.fits[0].pos_right)
    
def set_axis(sweep,x_min,x_max):
    plt.xlim(x_min,x_max)
    x = np.linspace(x_min,x_max)
    yl,yr = sweep.fits[j].yValue(x)
    y_min = np.min([yl,yr])
    y_max = np.max([yl,yr])
    l,h = t(y_min,y_max)
    plt.ylim(l,h)
    plt.yticks([y_min,y_max],(round(y_min,1),round(y_max,1)))
    x_low, x_high = np.percentile(x,[25,75])
    plt.xticks([int(x_low),int(x_high)])
    plt.tick_params(axis='y',pad=ypad)
    plt.tick_params(axis='x',pad=xpad)

# %%
i11 = Analysis.Run(np.load('2011_Raw.npy'), np.load('2011_Prune_strong_flat.npy'), Analysis.bval2011, np.load('2011bf_new_prune_flat_edit.npy')).prune_data
i14 = Analysis.Run(np.load('2014_Raw.npy'), np.load('2014_Prune_strong.npy'), Analysis.bval2014, np.load('2014bf_new_prune_edit.npy')).prune_data
soft11 = Analysis.Run(np.load('2011_Raw.npy'), np.load('2011_Prune_new_flat.npy'), Analysis.bval2011, np.load('2011bf_new_prune_flat_edit.npy')).prune_data
soft14 = Analysis.Run(np.load('2014_Raw.npy'), np.load('2014_Prune_new.npy'), Analysis.bval2014, np.load('2014bf_new_prune_edit.npy')).prune_data
se11 = np.load('2011se_flat_edit.npy')
se14 = np.load('2014se_edit.npy')
d140 = np.load('2014_0.npy')
d144 = np.load('2014_4.npy')

# %%
gs = GridSpec(1000,1000)

# %%
mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6*1.2])

right_space = 50
mid_space = 95
bot_space = 45
y_len = int((1000-4*bot_space)/4)
x_len = int((1000-right_space-mid_space)/2)
ypad = 2
xpad = 4

ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax1.annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-36,-28)
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

ax2 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:])
ax2.annotate('E', xy=(0.01, 0.88), xycoords="axes fraction")
n = 15
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-40,-31.2574)
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax3 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax3.annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax3.yaxis.set_label_coords(-0.25, -.10)
n = 19
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-33,-29)
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

ax4 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])
ax4.annotate('F', xy=(0.01, 0.88), xycoords="axes fraction")
n = 12
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-38.9048,-31.4369)
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax5 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax5.annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")
n = 2
j = 2
init_plot(i14[n])
i14[n].fits[2].plot_select('l','k',2,-20.6711,-18.8)
i14[n].fits[2].plot_select('r','r',2,-20.6711,-17.8369)
i14[n].fits[1].plot_select('l','r',2,-17.8369,-14.675)
i14[n].fits[1].plot_select('r','#00ff00',2,-18.8,-14.675)
set_axis(i14[n],-20.6711,-16)
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:])
ax6.annotate('G', xy=(0.01, 0.88), xycoords="axes fraction")
n = 7
j = 1
i14[n].plot_fit(j)
set_axis(i14[n],-19,-11)
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax7 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:x_len+right_space])
ax7.annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")
n = 3
init_plot(i14[n])
i14[n].fits[4].plot_select('b',['k','r'],[2,2],i14[n].fits[4].pos_left,-21.615)
i14[n].fits[3].plot_select('l','r',2,-21.615,-18.7532)
i14[n].fits[3].plot_select('r','#00ff00',2,-21.864,-18.7532)
set_axis(i14[n],-24.47,-18.78)
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


plt.xlabel('V$_{P}$ (mV)',size=12)
ax7.xaxis.set_label_coords(1.12, -.2)


ax8 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,x_len+right_space+mid_space:])
ax8.annotate('H', xy=(0.01, 0.88), xycoords="axes fraction")
n = 9
j = 1
i14[n].plot_fit(j,False)
set_axis(i14[n],-18,-9)
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

# %%
mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6*1.5,4.6*1.2])

right_space = int(50/1.5)
mid_space = int(90.0/(1.5))
bot_space = 45
y_len = int((1000-4*bot_space)/4)
x_len = int((1000-right_space-2*mid_space)/3)
ypad = 2
xpad = 4

#PI/4-------------------------------------------
ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax1.annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")
n = 2
j = 2
init_plot(i14[n])
i14[n].fits[2].plot_select('l','k',2,-20.6711,-18.8)
i14[n].fits[2].plot_select('r','r',2,-20.6711,-17.8369)
i14[n].fits[1].plot_select('l','r',2,-17.8369,-14.675)
i14[n].fits[1].plot_select('r','#00ff00',2,-18.8,-14.675)
set_axis(i14[n],-20.6711,-16)


ax3 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax3.annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax3.yaxis.set_label_coords(-0.25, -.10)
n = 3
j = 3
init_plot(i14[n])
i14[n].fits[4].plot_select('b',['k','r'],[2,2],i14[n].fits[4].pos_left,-21.615)
i14[n].fits[3].plot_select('l','r',2,-21.615,-18.7532)
i14[n].fits[3].plot_select('r','#00ff00',2,-21.864,-18.7532)
set_axis(i14[n],-24.47,-18.78)


ax5 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax5.annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-36,-28)


ax7 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:x_len+right_space])
ax7.annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")
n = 19
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-33,-29)


#PI-------------------------------------------------------

ax2 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:2*x_len+right_space+mid_space])
ax2.annotate('E', xy=(0.01, 0.88), xycoords="axes fraction")
n = 7
j = 1
i14[n].plot_fit(j)
set_axis(i14[n],-19,-11)


ax4 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:2*x_len+right_space+mid_space])
ax4.annotate('F', xy=(0.01, 0.88), xycoords="axes fraction")
n = 9
j = 1
i14[n].plot_fit(j,False)
set_axis(i14[n],-18,-9)


ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:2*x_len+right_space+mid_space])
ax6.annotate('G', xy=(0.01, 0.88), xycoords="axes fraction")
n = 12
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-38.9048,-31.4369)


ax8 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,x_len+right_space+mid_space:2*x_len+right_space+mid_space])
ax8.annotate('H', xy=(0.01, 0.88), xycoords="axes fraction")
plt.xlabel('V$_{P}$ (mV)',size=12)
n = 14
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-39,-30.3914)

#5PI/4-------------------------------------------------------------------

ax9 = plt.subplot(gs[:y_len,2*x_len+right_space+2*mid_space:3*x_len+right_space+2*mid_space])
ax9.annotate('I', xy=(0.01, 0.88), xycoords="axes fraction")
n = 3
j = 0
i14[n].plot_fit(j,False)
set_axis(i14[n],-12.5054,-5.28358)

ax10 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,2*x_len+right_space+2*mid_space:3*x_len+right_space+2*mid_space])
ax10.annotate('J', xy=(0.01, 0.88), xycoords="axes fraction")
n = 8
j = 1
i14[n].plot_fit(j,False)
set_axis(i14[n],-12.8875,-4.05681)

ax11 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,2*x_len+right_space+2*mid_space:3*x_len+right_space+2*mid_space])
ax11.annotate('K', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-41,-33)

ax12 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,2*x_len+right_space+2*mid_space:3*x_len+right_space+2*mid_space])
ax12.annotate('L', xy=(0.01, 0.88), xycoords="axes fraction")
n = 13
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-39,-30.2012)

# %%
fig.savefig('Slip Fits Figure v1',dpi=1200)

# %%
mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6*1.2*1.5])

right_space = int(50/1.5)
mid_space = 90
bot_space = 30
y_len = int((1000-5*bot_space)/6)
x_len = int((1000-right_space-2*mid_space)/2)
ypad = 2
xpad = 4

#PI/4-------------------------------------------
ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax1.annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")
n = 2
j = 2
init_plot(i14[n])
i14[n].fits[2].plot_select('l','k',2,-21.4367,-18.8)
i14[n].fits[2].plot_select('r','r',2,-21.4367,-17.8369)
i14[n].fits[1].plot_select('l','r',2,-17.8369,-13.76)
i14[n].fits[1].plot_select('r','#00ff00',2,-18.8,-13.76)
set_axis(i14[n],-21.4367,-13.76)


ax3 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax3.annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
n = 3
j = 3
init_plot(i14[n])
i14[n].fits[4].plot_select('b',['k','r'],[2,2],-26.8855,-21.615)
i14[n].fits[3].plot_select('l','r',2,-21.615,-18.41)
i14[n].fits[3].plot_select('r','#00ff00',2,-21.864,-18.41)
set_axis(i14[n],-26.8855,-18.41)



ax5 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax5.annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")
ax5.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax5.yaxis.set_label_coords(-0.25, -.10)
n = 5
j = 2
i14[n].plot_fit(j)
set_axis(i14[n],-28.77,-17.05)


ax7 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:x_len+right_space])
ax7.annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")
n = 7
j = 2
i14[n].plot_fit(j,False)
set_axis(i14[n],-27.85,-19.47)

ax9 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,right_space:x_len+right_space])
ax9.annotate('E', xy=(0.01, 0.88), xycoords="axes fraction")
j = 3
n = 8
init_plot(i14[n])
i14[n].fits[0].plot_select('l','k',2,i14[n].fits[0].pos_left,-25.3)
i14[n].fits[0].plot_select('r','r',2,i14[n].fits[0].pos_left,-23.439)
i14[n].fits[3].plot_select('l','r',2,-23.439,-17.463)
i14[n].fits[3].plot_select('r','#00ff00',2,-25.3,-17.463)
set_axis(i14[n],-31.0698,-18.2957)

ax11 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,right_space:x_len+right_space])
ax11.annotate('F', xy=(0.01, 0.88), xycoords="axes fraction")
plt.xlabel('V$_{P}$ (mV)',size=12)
ax11.xaxis.set_label_coords(1.12, -.2)
n = 0
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-36.16,-25.9677)

#PI & 5Pi/4-------------------------------------------------------

ax2 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:2*x_len+right_space+mid_space])
ax2.annotate('G', xy=(0.01, 0.88), xycoords="axes fraction")
n = 7
j = 1
i14[n].plot_fit(j)
set_axis(i14[n],-21.02,-10.42)

ax4 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:2*x_len+right_space+mid_space])
ax4.annotate('H', xy=(0.01, 0.88), xycoords="axes fraction")
n = 9
j = 1
i14[n].plot_fit(j,False)
set_axis(i14[n],-19.8524,-6.699)

ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:2*x_len+right_space+mid_space])
ax6.annotate('I', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-42.9385,-30.0926)

ax8 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,x_len+right_space+mid_space:2*x_len+right_space+mid_space])
ax8.annotate('J', xy=(0.01, 0.88), xycoords="axes fraction")
n = 1
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-27.3966,-17.1069)
plt.ylim([11.35,11.89])

ax10 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,x_len+right_space+mid_space:2*x_len+right_space+mid_space])
ax10.annotate('K', xy=(0.01, 0.88), xycoords="axes fraction")
n = 3
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-40.7668,-29.9666)

ax12 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,x_len+right_space+mid_space:2*x_len+right_space+mid_space])
ax12.annotate('L', xy=(0.01, 0.88), xycoords="axes fraction")
n = 14
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-41.6623,-30.424)

# %%
fig.savefig('Slip Fits Figure v2',dpi=1200)

# %%
fig, ax = plt.subplots(4, 1, figsize=(6.9,5))
ax[1].set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax[1].yaxis.set_label_coords(-.055, -0.08)
ax[3].set_xlabel('V$_{P}$ (mV)',size=12)

n = 0
plt.sca(ax[0])
init_plot(i14[n])
ax[0].annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")
i14[n].fits[3].plot_select('b',['k','r'],[2,2],-27.71,-20.3179)
i14[n].fits[2].plot_select('b',['r','#00ff00'],[2,2],-20.3179,-18.675)
i14[n].fits[1].plot_select('b',['#00ff00','orange'],[2,2],-18.675,-11.7825)
i14[n].fits[0].plot_select('b',['orange','k'],[2,2],-11.7825,-6.5)
set_axis(i14[n],-27.71,-6.98202)

plt.sca(ax[1])
ax[1].annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
n = 4
init_plot(i14[n])
i14[n].fits[1].plot_select('b',['k','r'],[2,2],-31,-17.7358)
i14[n].fits[0].plot_select('b',['r','#00ff00'],[2,2],-17.7358,i14[n].fits[0].pos_right)
set_axis(i14[n],-31,-6.9)

n = 5
plt.sca(ax[2])
ax[2].annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")
init_plot(i11[n])
#stitch(i11[n],-34.0052)
i11[n].fits[1].plot_select('b',['k','r'],[2,2],-44,-34.0052)
i11[n].fits[0].plot_select('b',['r','#00ff00'],[2,2],-34.0052,-22.7)
#set_axis(i11[n],-43.2812,-26.005)
set_axis(i11[n],-50.2812,-6.005)

n = 12
plt.sca(ax[3])
ax[3].annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")
init_plot(i11[n])
stitch(i11[n],-36.6826)
set_axis(i11[n],-42.4487,-31.3836)

# %%
fig.savefig('Full Sweeps v1',dpi=1200)

# %%
#Doing all fits:
fig, ax = plt.subplots(11, 4, figsize=(13,20))
plt.rc('font', size=6)
#-----------------------------------------------------------
#Pi/4-------------------------------------------------------
plt.sca(ax[0,0])
n = 0
j = 2
i14[n].plot_fit(j)
set_axis(i14[n],-21.98,-15.4199)
plt.title('-$\pi/4$')

plt.sca(ax[1,0])
n = 2
j = 2
init_plot(i14[n])
i14[n].fits[2].plot_select('l','k',2,-21.4367,-18.8)
i14[n].fits[2].plot_select('r','r',2,-21.4367,-17.8369)
i14[n].fits[1].plot_select('l','r',2,-17.8369,-13.76)
i14[n].fits[1].plot_select('r','#00ff00',2,-18.8,-13.76)
set_axis(i14[n],-21.4367,-13.76)

plt.sca(ax[2,0])
n = 3
j = 3
init_plot(i14[n])
i14[n].fits[4].plot_select('b',['k','r'],[2,2],-26.8855,-21.615)
i14[n].fits[3].plot_select('l','r',2,-21.615,-18.41)
i14[n].fits[3].plot_select('r','#00ff00',2,-21.864,-18.41)
set_axis(i14[n],-26.8855,-18.41)

plt.sca(ax[3,0])
n = 4
j = 1
i14[n].plot_fit(j)
set_axis(i14[n],-29.1536,-16.649)

plt.sca(ax[4,0])
n = 5
j = 2
i14[n].plot_fit(j)
set_axis(i14[n],-28.77,-17.05)

plt.sca(ax[5,0])
n = 7
j = 2
i14[n].plot_fit(j,False)
set_axis(i14[n],-27.85,-19.47)

plt.sca(ax[6,0])
j = 3
n = 8
init_plot(i14[n])
i14[n].fits[0].plot_select('l','k',2,i14[n].fits[0].pos_left,-25.3)
i14[n].fits[0].plot_select('r','r',2,i14[n].fits[0].pos_left,-23.439)
i14[n].fits[3].plot_select('l','r',2,-23.439,-17.463)
i14[n].fits[3].plot_select('r','#00ff00',2,-25.3,-17.463)
set_axis(i14[n],-31.0698,-18.2957)

plt.sca(ax[7,0])
n = 9
j = 0
i14[n].plot_fit(j)
set_axis(i14[n],-28.6476,-18.3355)

plt.sca(ax[8,0])
n = 0
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-36.16,-25.9677)

plt.sca(ax[9,0])
n = 5
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-35.2099,-21.8772)
plt.ylim([11.24,11.75])

plt.sca(ax[10,0])
n = 19
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-35.13,-25)
#Pi--------------------------------------------------------------------------------------------------------
n = 0
j = 1
plt.sca(ax[0,1])
i14[n].plot_fit(j)
set_axis(i14[n],-19.44,-8.5)
plt.title('$\pi$')

n = 4
j = 0
plt.sca(ax[1,1])
i14[n].plot_fit(j,False)
set_axis(i14[n],-20.6238,-7.18386)

n = 6
j = 0
plt.sca(ax[2,1])
i14[n].plot_fit(j,False)
set_axis(i14[n],-16.8153,-8.66815)

plt.sca(ax[3,1])
n = 7
j = 1
i14[n].plot_fit(j)
set_axis(i14[n],-21.02,-10.42)

n = 8
j = 2
plt.sca(ax[4,1])
i14[n].plot_fit(j)
set_axis(i14[n],-17.8737,-7.038)
plt.ylim([10.83,11.3156])

n = 9
j = 1
plt.sca(ax[5,1])
i14[n].plot_fit(j,False)
set_axis(i14[n],-19.8524,-6.699)

n = 13
j = 1
plt.sca(ax[6,1])
i14[n].plot_fit(j)
set_axis(i14[n],-27.8337,-17.99)

plt.sca(ax[7,1])
n = 1
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-27.3966,-17.1069)
plt.ylim([11.35,11.89])

n = 2
j = 0
plt.sca(ax[8,1])
i11[n].plot_fit(j)
set_axis(i11[n],-38.8884,-29.407)

plt.sca(ax[9,1])
n = 3
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-40.7668,-29.9666)

n = 5
j = 1
plt.sca(ax[10,1])
i11[n].plot_fit(j)
set_axis(i11[n],-43.576,-29.7477)

plt.sca(ax[0,2])
n = 6
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-45.2278,-30.5427)
plt.title('$\pi$')

n = 7
j = 0
plt.sca(ax[1,2])
i11[n].plot_fit(j)
set_axis(i11[n],-43.2709,-29.9271)

plt.sca(ax[2,2])
n = 8
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-40.4377,-30.6139)

n = 12
j = 0
plt.sca(ax[3,2])
i11[n].plot_fit(j)
set_axis(i11[n],-43.8794,-31.2702)

n = 14
j = 1
plt.sca(ax[4,2])
i11[n].plot_fit(j)
set_axis(i11[n],-41.6623,-30.424)

plt.sca(ax[5,2])
n = 15
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-42.7665,-30.0193)

n = 16
j = 0
plt.sca(ax[6,2])
i11[n].plot_fit(j)
set_axis(i11[n],-42.1981,-30.7757)

plt.sca(ax[7,2])
n = 19
j = 2
i11[n].plot_fit(j)
set_axis(i11[n],-41.1981,-31.6231)

n = 21
j = 0
plt.sca(ax[8,2])
i11[n].plot_fit(j)
set_axis(i11[n],-40.8065,-30.2016)

#5pi/4------------------------------------------------------------
#Sweep 2
n = 2
j = 0
plt.sca(ax[0,3])
i14[n].plot_fit(j,False)
set_axis(i14[n],-14.7645,-5.10853)
plt.title('$5\pi/4$')

n = 2
j = 3
plt.sca(ax[1,3])
i14[n].plot_fit(j,False)
set_axis(i14[n],-28.0675,-19.7205)

n = 3
j = 0
plt.sca(ax[2,3])
i14[n].plot_fit(j)
set_axis(i14[n],-13.3993,-5.28358)

n = 8
j = 1
plt.sca(ax[3,3])
i14[n].plot_fit(j,False)
set_axis(i14[n],-12.8875,-4.05681)

plt.sca(ax[4,3])
n = 0
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-42.9385,-30.0926)

n = 10
j = 0
plt.sca(ax[5,3])
i11[n].plot_fit(j)
set_axis(i11[n],-37.1228,-28.7668)

n = 13
j = 0
plt.sca(ax[6,3])
i11[n].plot_fit(j)
set_axis(i11[n],-43.1328,-30.0897)

# %%
fig.savefig('All Fits.jpg',dpi=1200)

# %%
run11 = Analysis.Run(np.load('2011_Raw.npy'), np.load('2011_Prune_strong_flat.npy'), Analysis.bval2011, np.load('2011bf_new_prune_flat_edit.npy'))
run14 = Analysis.Run(np.load('2014_Raw.npy'), np.load('2014_Prune_strong.npy'), Analysis.bval2011, np.load('2014bf_new_prune_edit.npy'))
i11 = run11.prune_data
i14 = run14.prune_data

# %%
fig, ax = plt.subplots(4, 1, figsize=(6.9,5))
ax[1].set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax[1].yaxis.set_label_coords(-.055, -0.08)
ax[3].set_xlabel('V$_{P}$ (mV)',size=12)


plt.sca(ax[0])
ax[0].annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 3
init_plot(i14[n])
i14[n].fits[3].plot_select('b',['k','r'],[2,2],-31,-19.8804)
i14[n].fits[2].plot_select('b',['r','#00ff00'],[2,2],-19.8804,-18.675)
i14[n].fits[1].plot_select('b',['#00ff00','orange'],[2,2],-18.675,-11.7825)
i14[n].fits[0].plot_select('b',['orange','k'],[2,2],-11.7825,-6.5)
set_axis(i14[n],-31,-6.98202)

plt.sca(ax[1])
ax[1].annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
n = 4
j = 1
init_plot(i14[n])
i14[n].fits[1].plot_select('b',['k','r'],[2,2],-31,-17.7358)
i14[n].fits[0].plot_select('b',['r','#00ff00'],[2,2],-17.7358,i14[n].fits[0].pos_right)
set_axis(i14[n],-31,-6.9)

plt.sca(ax[2])
ax[2].annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")
n = 5
init_plot(i11[n])
i11[n].fits[1].plot_select('b',['k','r'],[2,2],-44,-34.0052)
i11[n].fits[0].plot_select('b',['r','#00ff00'],[2,2],-34.0052,-10)
#set_axis(i11[n],-43.2812,-25.98)
set_axis(i11[n],-43.2815,-19.2)

plt.sca(ax[3])
ax[3].annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")
n = 12
init_plot(i11[n])
i11[n].fits[1].plot_select('b',['k','r'],[2,2],-44,-36.6826)
i11[n].fits[0].plot_select('b',['r','#00ff00'],[2,2],-36.6826,-31.67)
#set_axis(i11[n],-42.4487,-31.3836)
set_axis(i11[n],-42.4487,-22)

# %%
#Full and windows

mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[7.2,7.2*1.6])
gs = GridSpec(1000,1000)
num_y = 6
num_x = 2
right_space = 0
mid_space = 60
bot_space = 20
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
#-------------------------------------------------------------------------------
ax1 = plt.subplot(gs[:y_len,right_space:2*x_len+right_space+mid_space])
n = 0
j = 3
init_plot(i14[n])
i14[n].fits[3].plot_select('b',['k','r'],[2,2],-31,-19.8804)
i14[n].fits[2].plot_select('b',['r','#00ff00'],[2,2],-19.8804,-18.675)
i14[n].fits[1].plot_select('b',['#00ff00','orange'],[2,2],-18.675,-11.7825)
i14[n].fits[0].plot_select('b',['orange','k'],[2,2],-11.7825,-6.5)
set_axis(i14[n],-31,-6.98202)
plt.xticks([-30,-20,-10])

ax2 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:2*x_len+right_space+mid_space])
n = 4
j = 1
init_plot(i14[n])
i14[n].fits[1].plot_select('b',['k','r'],[2,2],-31,-17.7358)
i14[n].fits[0].plot_select('b',['r','#00ff00'],[2,2],-17.7358,i14[n].fits[0].pos_right)
set_axis(i14[n],-31,-7.19)
plt.xticks([-30,-20,-10])

ax3 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:2*x_len+right_space+mid_space])
n = 5
init_plot(i11[n])
i11[n].fits[1].plot_select('b',['k','r'],[2,2],-44,-34.0052)
i11[n].fits[0].plot_select('b',['r','#00ff00'],[2,2],-34.0052,-10)
set_axis(i11[n],-43.2812,-19.2)
plt.xticks([-40,-30,-20])

ax4 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:x_len+right_space])
n = 9
j = 1
i14[n].plot_fit(j)
set_axis(i14[n],-19.8524,-6.224)

ax5 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,right_space:x_len+right_space])
n = 0
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-42.9385,-30.0926)

ax6 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,right_space:x_len+right_space])
n = 14
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-41.6623,-30.424)

ax7 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
n = 2
j = 2
init_plot(i14[n])
i14[n].fits[2].plot_select('l','k',2,-21.4367,-18.8)
i14[n].fits[2].plot_select('r','r',2,-21.4367,-17.8369)
i14[n].fits[1].plot_select('l','r',2,-17.8369,-13.76)
i14[n].fits[1].plot_select('r','#00ff00',2,-18.8,-13.76)
set_axis(i14[n],-21.4367,-13.76)

ax8 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
n = 7
j = 2
i14[n].plot_fit(j,False)
set_axis(i14[n],-27.85,-19.47)

ax9 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
n = 0
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-36.16,-25.9677)

ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax3.yaxis.set_label_coords(-.05, 0)

ax9.set_xlabel('V$_{P}$ (mV)',size=12)
ax9.xaxis.set_label_coords(-0.05, -0.1)

# %%
fig.savefig('All Fit v1',dpi=1200)

# %%
#Full and windows v2

mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[7.2,7.2*1.6])
gs = GridSpec(1000,1000)
num_y = 6
num_x = 2
right_space = 0
mid_space = 60
bot_space = 20
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
#-------------------------------------------------------------------------------
ax1 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:2*x_len+right_space+mid_space])
n = 0
j = 3
init_plot(i14[n])
i14[n].fits[3].plot_select('b',['k','r'],[2,2],-31,-19.8804)
i14[n].fits[2].plot_select('b',['r','#00ff00'],[2,2],-19.8804,-18.675)
i14[n].fits[1].plot_select('b',['#00ff00','orange'],[2,2],-18.675,-11.7825)
i14[n].fits[0].plot_select('b',['orange','k'],[2,2],-11.7825,-6.5)
set_axis(i14[n],-31,-6.98202)
plt.xticks([-30,-20,-10])

ax2 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,right_space:2*x_len+right_space+mid_space])
n = 4
j = 1
init_plot(i14[n])
i14[n].fits[1].plot_select('b',['k','r'],[2,2],-31,-17.7358)
i14[n].fits[0].plot_select('b',['r','#00ff00'],[2,2],-17.7358,i14[n].fits[0].pos_right)
set_axis(i14[n],-31,-7.19)
plt.xticks([-30,-20,-10])

ax3 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,right_space:2*x_len+right_space+mid_space])
n = 5
init_plot(i11[n])
i11[n].fits[1].plot_select('b',['k','r'],[2,2],-44,-34.0052)
i11[n].fits[0].plot_select('b',['r','#00ff00'],[2,2],-34.0052,-10)
set_axis(i11[n],-43.2812,-19.2)
plt.xticks([-40,-30,-20])

ax4 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
n = 9
j = 1
i14[n].plot_fit(j)
set_axis(i14[n],-19.8524,-6.224)

ax5 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
n = 0
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-42.9385,-30.0926)

ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
n = 14
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-41.6623,-30.424)

ax7 = plt.subplot(gs[:y_len,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
n = 2
j = 2
init_plot(i14[n])
i14[n].fits[2].plot_select('l','k',2,-21.4367,-18.8)
i14[n].fits[2].plot_select('r','r',2,-21.4367,-17.8369)
i14[n].fits[1].plot_select('l','r',2,-17.8369,-13.76)
i14[n].fits[1].plot_select('r','#00ff00',2,-18.8,-13.76)
set_axis(i14[n],-21.4367,-13.76)

ax8 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
n = 7
j = 2
i14[n].plot_fit(j,False)
set_axis(i14[n],-27.85,-19.47)

ax9 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
n = 0
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-36.16,-25.9677)

ax1.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax1.yaxis.set_label_coords(-.05, 1.1)

ax3.set_xlabel('V$_{P}$ (mV)',size=12)
#ax9.xaxis.set_label_coords(-0.05, -0.1)

# %%
fig.savefig('All Fit v2',dpi=1200)

# %%
#Full and windows v3

mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[10,4.5])
gs = GridSpec(1000,1000)
num_y = 3
num_x = 4
right_space = 0
mid_space = 36
bot_space = 46
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
#-------------------------------------------------------------------------------
ax1 = plt.subplot(gs[:y_len,right_space:2*x_len+right_space+mid_space])
n = 0
j = 3
init_plot(i14[n])
i14[n].fits[3].plot_select('b',['k','r'],[2,2],-31,-19.8804)
i14[n].fits[2].plot_select('b',['r','#00ff00'],[2,2],-19.8804,-18.675)
i14[n].fits[1].plot_select('b',['#00ff00','orange'],[2,2],-18.675,-11.7825)
i14[n].fits[0].plot_select('b',['orange','k'],[2,2],-11.7825,-6.5)
set_axis(i14[n],-31,-6.98202)
plt.xticks([-30,-20,-10])

ax2 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:2*x_len+right_space+mid_space])
n = 4
j = 1
init_plot(i14[n])
i14[n].fits[1].plot_select('b',['k','r'],[2,2],-31,-17.7358)
i14[n].fits[0].plot_select('b',['r','#00ff00'],[2,2],-17.7358,i14[n].fits[0].pos_right)
set_axis(i14[n],-31,-7.19)
plt.xticks([-30,-20,-10])

ax3 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:2*x_len+right_space+mid_space])
n = 5
init_plot(i11[n])
i11[n].fits[1].plot_select('b',['k','r'],[2,2],-44,-34.0052)
i11[n].fits[0].plot_select('b',['r','#00ff00'],[2,2],-34.0052,-10)
set_axis(i11[n],-43.2812,-19.2)
plt.xticks([-40,-30,-20])

ax4 = plt.subplot(gs[:y_len,2*x_len+right_space+2*mid_space:3*x_len+right_space+2*mid_space])
n = 9
j = 1
i14[n].plot_fit(j)
set_axis(i14[n],-19.8524,-6.224)

ax5 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,2*x_len+right_space+2*mid_space:3*x_len+right_space+2*mid_space])
n = 0
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-42.9385,-30.0926)

ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,2*x_len+right_space+2*mid_space:3*x_len+right_space+2*mid_space])
n = 14
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-41.6623,-30.424)

ax7 = plt.subplot(gs[:y_len,3*x_len+right_space+3*mid_space:4*x_len+right_space+3*mid_space])
n = 2
j = 2
init_plot(i14[n])
i14[n].fits[2].plot_select('l','k',2,-21.4367,-18.8)
i14[n].fits[2].plot_select('r','r',2,-21.4367,-17.8369)
i14[n].fits[1].plot_select('l','r',2,-17.8369,-13.76)
i14[n].fits[1].plot_select('r','#00ff00',2,-18.8,-13.76)
set_axis(i14[n],-21.4367,-13.76)

ax8 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,3*x_len+right_space+3*mid_space:4*x_len+right_space+3*mid_space])
n = 7
j = 2
i14[n].plot_fit(j,False)
set_axis(i14[n],-27.85,-19.47)

ax9 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,3*x_len+right_space+3*mid_space:4*x_len+right_space+3*mid_space])
n = 0
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-36.16,-25.9677)

ax2.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
#ax2.yaxis.set_label_coords(0, 0)

ax6.set_xlabel('V$_{P}$ (mV)',size=12)
ax6.xaxis.set_label_coords(-0.05, -0.18)

# %%
fig.savefig('All Fit v3',dpi=1200)

# %%
#Full and windows v4

mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[10,4.5])
gs = GridSpec(1000,1000)
num_y = 3
num_x = 4
right_space = 0
mid_space = 36
bot_space = 46
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
#-------------------------------------------------------------------------------
ax1 = plt.subplot(gs[:y_len,2*x_len+right_space+2*mid_space:4*x_len+right_space+3*mid_space])
n = 0
j = 3
init_plot(i14[n])
i14[n].fits[3].plot_select('b',['k','r'],[2,2],-31,-19.8804)
i14[n].fits[2].plot_select('b',['r','#00ff00'],[2,2],-19.8804,-18.675)
i14[n].fits[1].plot_select('b',['#00ff00','orange'],[2,2],-18.675,-11.7825)
i14[n].fits[0].plot_select('b',['orange','k'],[2,2],-11.7825,-6.5)
set_axis(i14[n],-31,-6.98202)
plt.xticks([-30,-20,-10])

ax2 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,2*x_len+right_space+2*mid_space:4*x_len+right_space+3*mid_space])
n = 4
j = 1
init_plot(i14[n])
i14[n].fits[1].plot_select('b',['k','r'],[2,2],-31,-17.7358)
i14[n].fits[0].plot_select('b',['r','#00ff00'],[2,2],-17.7358,i14[n].fits[0].pos_right)
set_axis(i14[n],-31,-7.19)
plt.xticks([-30,-20,-10])

ax3 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,2*x_len+right_space+2*mid_space:4*x_len+right_space+3*mid_space])
n = 5
init_plot(i11[n])
i11[n].fits[1].plot_select('b',['k','r'],[2,2],-44,-34.0052)
i11[n].fits[0].plot_select('b',['r','#00ff00'],[2,2],-34.0052,-10)
set_axis(i11[n],-43.2812,-19.2)
plt.xticks([-40,-30,-20])

ax4 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
n = 9
j = 1
i14[n].plot_fit(j)
set_axis(i14[n],-19.8524,-6.224)

ax5 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
n = 0
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-42.9385,-30.0926)

ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
n = 14
j = 1
i11[n].plot_fit(j)
set_axis(i11[n],-41.6623,-30.424)

ax7 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:2*x_len+right_space+mid_space])
n = 2
j = 2
init_plot(i14[n])
i14[n].fits[2].plot_select('l','k',2,-21.4367,-18.8)
i14[n].fits[2].plot_select('r','r',2,-21.4367,-17.8369)
i14[n].fits[1].plot_select('l','r',2,-17.8369,-13.76)
i14[n].fits[1].plot_select('r','#00ff00',2,-18.8,-13.76)
set_axis(i14[n],-21.4367,-13.76)

ax8 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:2*x_len+right_space+mid_space])
n = 7
j = 2
i14[n].plot_fit(j,False)
set_axis(i14[n],-27.85,-19.47)

ax9 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:2*x_len+right_space+mid_space])
n = 0
j = 0
i11[n].plot_fit(j)
set_axis(i11[n],-36.16,-25.9677)

ax5.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
#ax2.yaxis.set_label_coords(0, 0)

ax3.set_xlabel('V$_{P}$ (mV)',size=12)
ax3.xaxis.set_label_coords(-0.05, -0.18)

# %%
fig.savefig('All Fit v4',dpi=1200)

# %%
#Full and windows v2.1

mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[7.2,7.2*1.2])
gs = GridSpec(1000,1000)
num_y = 6
num_x = 2
right_space = 0
mid_space = 60
bot_space = 25
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
lw = 4
#-------------------------------------------------------------------------------
#Altered pruned data:
d140 = np.load('2014_0.npy')
d144 = np.load('2014_4.npy')
d149 = np.load('2014_9.npy')
d110 = np.load('2011_0.npy')

#-------------------------------------------------------------------------------
ax1 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:2*x_len+right_space+mid_space])
ax1.annotate('G', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 3
plt.plot(d140[0],d140[1])
i14[n].fits[3].plot_select('b',['k','r'],[lw,lw],-31,-19.8804)
i14[n].fits[2].plot_select('b',['r','#00ff00'],[lw,lw],-19.8804,-18.675)
i14[n].fits[1].plot_select('b',['#00ff00','orange'],[lw,lw],-18.675,-11.7825)
i14[n].fits[0].plot_select('b',['orange','k'],[lw,lw],-11.7825,-6.5)
set_axis(i14[n],-31,-6.98202)
plt.xticks([-30,-20,-10])

ax2 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,right_space:2*x_len+right_space+mid_space])
ax2.annotate('H', xy=(0.01, 0.88), xycoords="axes fraction")
n = 4
j = 1
plt.plot(d144[0],d144[1])
i14[n].fits[1].plot_select('b',['k','r'],[lw,lw],-31,-17.7358)
i14[n].fits[0].plot_select('b',['r','#00ff00'],[lw,lw],-17.7358,i14[n].fits[0].pos_right)
set_axis(i14[n],-31,-7.19)
plt.xticks([-30,-20,-10])

ax3 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,right_space:2*x_len+right_space+mid_space])
ax3.annotate('I', xy=(0.01, 0.88), xycoords="axes fraction")
n = 5
init_plot(i11[n])
i11[n].fits[1].plot_select('b',['k','r'],[lw,lw],-44,-34.0052)
i11[n].fits[0].plot_select('b',['r','#00ff00'],[lw,lw],-34.0052,-10)
set_axis(i11[n],-43.2812,-19.2)
plt.xticks([-40,-30,-20])

ax4 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax4.annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")
n = 9
j = 1
plt.plot(d149[0],d149[1])
i14[n].fits[j].plot_select('b',['k','r'],[lw,lw],-19.8524,-6.437)
set_axis(i14[n],-19.8524,-8)
plt.xticks([-15,-10])

ax5 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax5.annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
n = 8
j = 0
init_plot(i11[n])
i11[n].fits[j].plot_select('b',['k','r'],[lw,lw],-40.4377,-30.6139)
set_axis(i11[n],-40.4377,-30.6139)
plt.xticks([-40,-35])

ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax6.annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")
n = 14
j = 1
init_plot(i11[n])
i11[n].fits[j].plot_select('b',['k','r'],[lw,lw],-41.6623,-30.424)
set_axis(i11[n],-41.6623,-30.424)
plt.xticks([-40,-35])

ax7 = plt.subplot(gs[:y_len,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax7.annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")
n = 2
j = 2
init_plot(i14[n])
i14[n].fits[2].plot_select('l','k',lw,-21.4367,-18.8)
i14[n].fits[2].plot_select('r','r',lw,-21.4367,-17.8369)
i14[n].fits[1].plot_select('l','r',lw,-17.8369,-13.76)
i14[n].fits[1].plot_select('r','#00ff00',lw,-18.8,-13.76)
set_axis(i14[n],-21.4367,-13.76)
plt.xticks([-20,-15])

ax8 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax8.annotate('E', xy=(0.01, 0.88), xycoords="axes fraction")
n = 7
j = 2
init_plot(i14[n])
i14[n].fits[j].plot_select('b',['k','r'],[lw,lw],-27.85,-19.47)
set_axis(i14[n],-27.85,-19.47)
plt.xticks([-25,-20])

ax9 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax9.annotate('F', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 0
plt.plot(d110[0],d110[1])
i11[n].fits[j].plot_select('b',['k','r'],[lw,lw],-36.1293,-27.9345)
set_axis(i11[n],-36.1293,-27.9345)
plt.xticks([-35,-30])

ax1.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax1.yaxis.set_label_coords(-.05, 1.1)

ax3.set_xlabel('V$_{P}$ (mV)',size=12)
#ax9.xaxis.set_label_coords(-0.05, -0.1)

# %%
fig.savefig('All Fit v2_1',dpi=1200)

# %%
#Full and windows v2.3

mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[7.2,7.2*1.2])
gs = GridSpec(1000,1000)
num_y = 6
num_x = 2
right_space = 0
mid_space = 60
bot_space = 25
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
lw = 3
#-------------------------------------------------------------------------------
#Altered pruned data:
d140 = np.load('2014_0.npy')
d144 = np.load('2014_4.npy')
d149 = np.load('2014_9.npy')
d110 = np.load('2011_0.npy')

#-------------------------------------------------------------------------------
ax1 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:2*x_len+right_space+mid_space])
ax1.annotate('G', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 3
plt.plot(d140[0],d140[1])
i14[n].fits[3].plot_select('l','k',lw,-31,-22.1535)
i14[n].fits[3].plot_select('l','k',lw,-22.1535,-19.8804,'--')

i14[n].fits[3].plot_select('r','r',lw,-31,-22.1535,'--')
i14[n].fits[3].plot_select('r','r',lw,-22.1535,-19.8804)

i14[n].fits[2].plot_select('l','r',lw,-19.8804,-19.4419)
i14[n].fits[2].plot_select('l','r',lw,-19.4419,-19.0109,'--')

i14[n].fits[2].plot_select('r','#00ff00',lw,-20.99,-19.4419,'--')
i14[n].fits[2].plot_select('r','#00ff00',lw,-19.4419,-18.675)
i14[n].fits[1].plot_select('l','#00ff00',lw,-18.675,-14.87)
i14[n].fits[1].plot_select('l','#00ff00',lw,-14.87,-10.93,'--')

i14[n].fits[1].plot_select('r','orange',lw,-18.675,-14.87,'--')
i14[n].fits[1].plot_select('r','orange',lw,-14.87,-11.7825)
i14[n].fits[0].plot_select('l','orange',lw,-11.7825,-8.417)
i14[n].fits[0].plot_select('l','orange',lw,-8.417,-6.98202,'--')

i14[n].fits[0].plot_select('r','k',lw,-10.8774,-8.417,'--')
i14[n].fits[0].plot_select('r','k',lw,-8.417,-6.98202)
set_axis(i14[n],-31,-6.98202)
plt.xticks([-30,-20,-10])

ax2 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,right_space:2*x_len+right_space+mid_space])
ax2.annotate('H', xy=(0.01, 0.88), xycoords="axes fraction")
n = 4
j = 1
plt.plot(d144[0],d144[1])
i14[n].fits[1].plot_select('l','k',lw,-31,-21.7726)
i14[n].fits[1].plot_select('l','k',lw,-21.7726,-17.7358,'--')

i14[n].fits[1].plot_select('r','r',lw,-31,-21.7726,'--')
i14[n].fits[1].plot_select('r','r',lw,-21.7726,-17.7358)

i14[n].fits[0].plot_select('l','r',lw,-17.7358,-14.4199)
i14[n].fits[0].plot_select('l','r',lw,-14.4199,-7.19,'--')

i14[n].fits[0].plot_select('r','#00ff00',lw,-17.7358,-14.4199,'--')
i14[n].fits[0].plot_select('r','#00ff00',lw,-14.4199,-7.19)
set_axis(i14[n],-31,-7.19)
plt.xticks([-30,-20,-10])

ax3 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,right_space:2*x_len+right_space+mid_space])
ax3.annotate('I', xy=(0.01, 0.88), xycoords="axes fraction")
n = 5
init_plot(i11[n])
i11[n].fits[1].plot_select('l','k',lw,-44,-35.2168)
i11[n].fits[1].plot_select('l','k',lw,-35.2168,-32.76,'--')

i11[n].fits[1].plot_select('r','r',lw,-44,-35.2168,'--')
i11[n].fits[1].plot_select('r','r',lw,-35.2168,-34.0052)

i11[n].fits[0].plot_select('l','r',lw,-34.0052,-30.2804)
i11[n].fits[0].plot_select('l','r',lw,-30.2804,-10,'--')

i11[n].fits[0].plot_select('r','#00ff00',lw,-34.0052,-30.2804,'--')
i11[n].fits[0].plot_select('r','#00ff00',lw,-30.2804,-10)
set_axis(i11[n],-43.2812,-21.5518)
plt.xticks([-40,-30])

ax4 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax4.annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")
n = 9
j = 1
plt.plot(d149[0],d149[1])
i14[n].fits[j].plot_select('l','k',lw,-19.8524,-13.9762)
i14[n].fits[j].plot_select('l','k',lw,-13.9762,-6.437,'--')
i14[n].fits[j].plot_select('r','r',lw,-13.9762,-6.437)
i14[n].fits[j].plot_select('r','r',lw,-19.8524,-13.9762,'--')
set_axis(i14[n],-19.8524,-8)
plt.xticks([-15,-10])

ax5 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax5.annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
n = 8
j = 0
init_plot(i11[n])
i11[n].fits[j].plot_select('l','k',lw,-40.4377,-35.138)
i11[n].fits[j].plot_select('l','k',lw,-35.138,-34.0386,'--')
i11[n].fits[j].plot_select('l','k',lw,-34.0386,-33.4822)
i11[n].fits[j].plot_select('l','k',lw,-33.4822,-30.6139,'--')
i11[n].fits[j].plot_select('r','r',lw,-40.4377,-35.138,'--')
i11[n].fits[j].plot_select('r','r',lw,-35.138,-34.0386)
i11[n].fits[j].plot_select('r','r',lw,-34.0386,-33.4822,'--')
i11[n].fits[j].plot_select('r','r',lw,-33.4822,-30.6139)
set_axis(i11[n],-40.4377,-30.6139)
plt.xticks([-40,-35])

ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax6.annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")
n = 14
j = 1
init_plot(i11[n])
i11[n].fits[j].plot_select('l','k',lw,-41.6623,-34.0011)
i11[n].fits[j].plot_select('l','k',lw,-34.0011,-30.424,'--')
i11[n].fits[j].plot_select('r','r',lw,-41.6623,-34.0011,'--')
i11[n].fits[j].plot_select('r','r',lw,-34.0011,-30.424)
set_axis(i11[n],-41.6623,-30.424)
plt.xticks([-40,-35])

ax7 = plt.subplot(gs[:y_len,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax7.annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")
n = 2
j = 2
init_plot(i14[n])
i14[n].fits[2].plot_select('l','k',lw,-21.4367,-19.6676)
i14[n].fits[2].plot_select('l','k',lw,-19.6676,-13.76,'--')

i14[n].fits[2].plot_select('r','r',lw,-21.4367,-19.6676,'--')
i14[n].fits[2].plot_select('r','r',lw,-19.6676,-18.6335)
i14[n].fits[2].plot_select('r','r',lw,-18.6335,-18.223,'--')
i14[n].fits[2].plot_select('r','r',lw,-18.223,-17.8369)
i14[n].fits[1].plot_select('l','r',lw,-17.8369,-17.7601)
i14[n].fits[1].plot_select('l','r',lw,-17.7601,-17.4343,'--')
i14[n].fits[1].plot_select('l','r',lw,-17.343,-13.76)

i14[n].fits[1].plot_select('r','#00ff00',lw,-21.4367,-18.6335,'--')
i14[n].fits[1].plot_select('r','#00ff00',lw,-18.6335,-18.223)
i14[n].fits[1].plot_select('r','#00ff00',lw,-18.223,-17.7601,'--')
i14[n].fits[1].plot_select('r','#00ff00',lw,-17.7601,-17.4343)
i14[n].fits[1].plot_select('r','#00ff00',lw,-17.343,-13.76,'--')


set_axis(i14[n],-21.4367,-13.76)
plt.xticks([-20,-15])

ax8 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax8.annotate('E', xy=(0.01, 0.88), xycoords="axes fraction")
n = 7
j = 2
init_plot(i14[n])
i14[n].fits[j].plot_select('l','k',lw,-27.85,-21.9669)
i14[n].fits[j].plot_select('l','k',lw,-21.9669,-21.0443,'--')
i14[n].fits[j].plot_select('l','k',lw,-21.0443,-19.47)

i14[n].fits[j].plot_select('r','r',lw,-27.85,-21.9669,'--')
i14[n].fits[j].plot_select('r','r',lw,-21.9669,-21.0443)
i14[n].fits[j].plot_select('r','r',lw,-21.0443,-19.47,'--')
set_axis(i14[n],-27.85,-19.47)
plt.xticks([-25,-20])

ax9 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax9.annotate('F', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 0
plt.plot(d110[0],d110[1])
i11[n].fits[j].plot_select('l','k',lw,-36.1293,-30.0753)
i11[n].fits[j].plot_select('l','k',lw,-30.0753,-27.9345,'--')

i11[n].fits[j].plot_select('r','r',lw,-36.1293,-30.0753,'--')
i11[n].fits[j].plot_select('r','r',lw,-30.0753,-27.9345)

set_axis(i11[n],-36.1293,-27.9345)
plt.xticks([-35,-30])

ax1.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax1.yaxis.set_label_coords(-.05, 1.1)

ax3.set_xlabel('V$_{P}$ (mV)',size=12)
#ax9.xaxis.set_label_coords(-0.05, -0.1)

# %%
fig.savefig('All Fit v2_3',dpi=1200)

# %%
#Full and windows v2.4

mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[7.2,7.2*1.2])
gs = GridSpec(1000,1000)
num_y = 6
num_x = 2
right_space = 0
mid_space = 60
bot_space = 25
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
lw = 3
#-------------------------------------------------------------------------------
#Altered pruned data:
d140 = np.load('2014_0.npy')
d144 = np.load('2014_4.npy')
d149 = np.load('2014_9.npy')
d110 = np.load('2011_0.npy')

#-------------------------------------------------------------------------------
ax1 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:2*x_len+right_space+mid_space])
ax1.annotate('G', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 3
plt.plot(d140[0],d140[1])
i14[n].fits[3].plot_select('l','k',lw,-31,-22.1535)
i14[n].fits[3].plot_select('l','k',lw,-22.1535,-19.8804,'--')

i14[n].fits[3].plot_select('r','r',lw,-31,-22.1535,'--')
i14[n].fits[3].plot_select('r','r',lw,-22.1535,-19.8804)

i14[n].fits[2].plot_select('l','r',lw,-19.8804,-19.4419)
i14[n].fits[2].plot_select('l','r',lw,-19.4419,-19.0109,'--')

i14[n].fits[2].plot_select('r','#00ff00',lw,-20.99,-19.4419,'--')
i14[n].fits[2].plot_select('r','#00ff00',lw,-19.4419,-18.675)
i14[n].fits[1].plot_select('l','#00ff00',lw,-18.675,-14.87)
i14[n].fits[1].plot_select('l','#00ff00',lw,-14.87,-10.93,'--')

i14[n].fits[1].plot_select('r','orange',lw,-18.675,-14.87,'--')
i14[n].fits[1].plot_select('r','orange',lw,-14.87,-11.7825)
i14[n].fits[0].plot_select('l','orange',lw,-11.7825,-8.417)
i14[n].fits[0].plot_select('l','orange',lw,-8.417,-6.98202,'--')

i14[n].fits[0].plot_select('r','k',lw,-10.8774,-8.417,'--')
i14[n].fits[0].plot_select('r','k',lw,-8.417,-6.98202)
set_axis(i14[n],-31,-6.98202)
plt.xticks([-30,-20,-10])

ax2 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,right_space:2*x_len+right_space+mid_space])
ax2.annotate('H', xy=(0.01, 0.88), xycoords="axes fraction")
n = 4
j = 1
plt.plot(d144[0],d144[1])
i14[n].fits[1].plot_select('l','k',lw,-31,-21.7726)
i14[n].fits[1].plot_select('l','k',lw,-21.7726,-17.7358,'--')

i14[n].fits[1].plot_select('r','r',lw,-31,-21.7726,'--')
i14[n].fits[1].plot_select('r','r',lw,-21.7726,-17.7358)

i14[n].fits[0].plot_select('l','r',lw,-17.7358,-14.4199)
i14[n].fits[0].plot_select('l','r',lw,-14.4199,-7.19,'--')

i14[n].fits[0].plot_select('r','#00ff00',lw,-17.7358,-14.4199,'--')
i14[n].fits[0].plot_select('r','#00ff00',lw,-14.4199,-7.19)
set_axis(i14[n],-31,-7.19)
plt.xticks([-30,-20,-10])

ax3 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,right_space:2*x_len+right_space+mid_space])
ax3.annotate('I', xy=(0.01, 0.88), xycoords="axes fraction")
n = 5
init_plot(i11[n])
i11[n].fits[1].plot_select('l','k',lw,-44,-35.2168)
i11[n].fits[1].plot_select('l','k',lw,-35.2168,-32.76,'--')

i11[n].fits[1].plot_select('r','r',lw,-44,-35.2168,'--')
i11[n].fits[1].plot_select('r','r',lw,-35.2168,-34.0052)

i11[n].fits[0].plot_select('l','r',lw,-34.0052,-30.2804)
i11[n].fits[0].plot_select('l','r',lw,-30.2804,-10,'--')

i11[n].fits[0].plot_select('r','#00ff00',lw,-34.0052,-30.2804,'--')
i11[n].fits[0].plot_select('r','#00ff00',lw,-30.2804,-10)
set_axis(i11[n],-43.2812,-21.5518)
plt.xticks([-40,-30])

ax4 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax4.annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")
n = 9
j = 1
plt.plot(d149[0],d149[1])
i14[n].fits[j].plot_select('l','k',lw,-19.8524,-13.9762)
i14[n].fits[j].plot_select('l','k',lw,-13.9762,-6.437,'--')
i14[n].fits[j].plot_select('r','r',lw,-13.9762,-6.437)
i14[n].fits[j].plot_select('r','r',lw,-19.8524,-13.9762,'--')
set_axis(i14[n],-19.8524,-8)
plt.xticks([-15,-10])

ax5 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax5.annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
n = 8
j = 0
init_plot(i11[n])
i11[n].fits[j].plot_select('l','k',lw,-40.4377,-35.138)
i11[n].fits[j].plot_select('l','k',lw,-35.138,-34.0386,'--')
i11[n].fits[j].plot_select('l','k',lw,-34.0386,-33.4822)
i11[n].fits[j].plot_select('l','k',lw,-33.4822,-30.6139,'--')
i11[n].fits[j].plot_select('r','r',lw,-40.4377,-35.138,'--')
i11[n].fits[j].plot_select('r','r',lw,-35.138,-34.0386)
i11[n].fits[j].plot_select('r','r',lw,-34.0386,-33.4822,'--')
i11[n].fits[j].plot_select('r','r',lw,-33.4822,-30.6139)
set_axis(i11[n],-40.4377,-30.6139)
plt.xticks([-40,-35])

ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax6.annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")
n = 14
j = 1
init_plot(i11[n])
i11[n].fits[j].plot_select('l','k',lw,-41.6623,-34.0011)
i11[n].fits[j].plot_select('l','k',lw,-34.0011,-30.424,'--')
i11[n].fits[j].plot_select('r','r',lw,-41.6623,-34.0011,'--')
i11[n].fits[j].plot_select('r','r',lw,-34.0011,-30.424)
set_axis(i11[n],-41.6623,-30.424)
plt.xticks([-40,-35])

ax7 = plt.subplot(gs[:y_len,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax7.annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")
n = 2
j = 2
init_plot(i14[n])
i14[n].fits[2].plot_select('l','k',lw,-21.4367,-19.6676)
i14[n].fits[2].plot_select('l','k',lw,-19.6676,-13.76,'--')

i14[n].fits[2].plot_select('r','r',lw,-21.4367,-19.6676,'--')
i14[n].fits[2].plot_select('r','r',lw,-19.6676,-18.6335)
i14[n].fits[2].plot_select('r','r',lw,-18.6335,-18.223,'--')
i14[n].fits[2].plot_select('r','r',lw,-18.223,-17.8369)
i14[n].fits[1].plot_select('l','r',lw,-17.8369,-17.7601)
i14[n].fits[1].plot_select('l','r',lw,-17.7601,-17.4343,'--')
i14[n].fits[1].plot_select('l','r',lw,-17.343,-13.76)

i14[n].fits[1].plot_select('r','#00ff00',lw,-21.4367,-18.6335,'--')
i14[n].fits[1].plot_select('r','#00ff00',lw,-18.6335,-18.223)
i14[n].fits[1].plot_select('r','#00ff00',lw,-18.223,-17.7601,'--')
i14[n].fits[1].plot_select('r','#00ff00',lw,-17.7601,-17.4343)
i14[n].fits[1].plot_select('r','#00ff00',lw,-17.343,-13.76,'--')


set_axis(i14[n],-21.4367,-13.76)
plt.xticks([-20,-15])

ax8 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax8.annotate('E', xy=(0.01, 0.88), xycoords="axes fraction")
n = 7
j = 2
init_plot(i14[n])
i14[n].fits[j].plot_select('l','k',lw,-27.85,-21.9669)
i14[n].fits[j].plot_select('l','k',lw,-21.9669,-21.0443,'--')
i14[n].fits[j].plot_select('l','k',lw,-21.0443,-19.47)

i14[n].fits[j].plot_select('r','r',lw,-27.85,-21.9669,'--')
i14[n].fits[j].plot_select('r','r',lw,-21.9669,-21.0443)
i14[n].fits[j].plot_select('r','r',lw,-21.0443,-19.47,'--')
set_axis(i14[n],-27.85,-19.47)
plt.xticks([-25,-20])

ax9 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax9.annotate('F', xy=(0.01, 0.88), xycoords="axes fraction")
soft = Analysis.Run(np.load('2011_Raw.npy'), np.load('2011_Prune_new_flat.npy'), Analysis.bval2011, np.load('2011bf_new_prune_flat_edit.npy')).prune_data
n = 19
j = 1
init_plot(soft[n])
i11[n].fits[j].plot_select('l','k',lw,-35.0326,-31.5792)
i11[n].fits[j].plot_select('l','k',lw,-31.5792,-25.2446,'--')

i11[n].fits[j].plot_select('r','r',lw,-35.0326,-31.5792,'--')
i11[n].fits[j].plot_select('r','r',lw,-31.5792,-25.2446)

set_axis(i11[n],-35.0326,-25.2446)
plt.xticks([-35,-30])

ax1.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax1.yaxis.set_label_coords(-.05, 1.1)

ax3.set_xlabel('V$_{P}$ (mV)',size=12)
#ax9.xaxis.set_label_coords(-0.05, -0.1)

# %%
fig.savefig('All Fit v2_4',dpi=1200)

# %%
#Full and windows v2.5
mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[7.2,7.2*1.2])
gs = GridSpec(1000,1000)
num_y = 6
num_x = 2
right_space = 0
mid_space = 60
bot_space = 25
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
lw = 3
#-------------------------------------------------------------------------------
#Altered pruned data:
d140 = np.load('2014_0.npy')
d144 = np.load('2014_4.npy')
d149 = np.load('2014_9.npy')
d110 = np.load('2011_0.npy')

se11 = np.load('2011se_flat_edit.npy')
se14 = np.load('2014se_edit.npy')

#-------------------------------------------------------------------------------
ax1 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:2*x_len+right_space+mid_space])
ax1.annotate('G', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 3
plt.plot(d140[0],d140[1])
i14[n].fits[3].plot_select('l','k',lw,-31,-22.1535)
i14[n].fits[3].plot_select('l','k',lw,-22.1535,-19.8804,'--')

i14[n].fits[3].plot_select('r','r',lw,-31,-22.1535,'--')
i14[n].fits[3].plot_select('r','r',lw,-22.1535,-19.8804)

i14[n].fits[2].plot_select('l','r',lw,-19.8804,-19.4419)
i14[n].fits[2].plot_select('l','r',lw,-19.4419,-19.0109,'--')

i14[n].fits[2].plot_select('r','#00ff00',lw,-20.99,-19.4419,'--')
i14[n].fits[2].plot_select('r','#00ff00',lw,-19.4419,-18.675)
i14[n].fits[1].plot_select('l','#00ff00',lw,-18.675,-14.87)
i14[n].fits[1].plot_select('l','#00ff00',lw,-14.87,-10.93,'--')

i14[n].fits[1].plot_select('r','orange',lw,-18.675,-14.87,'--')
i14[n].fits[1].plot_select('r','orange',lw,-14.87,-11.7825)
i14[n].fits[0].plot_select('l','orange',lw,-11.7825,-8.417)
i14[n].fits[0].plot_select('l','orange',lw,-8.417,-6.98202,'--')

i14[n].fits[0].plot_select('r','k',lw,-10.8774,-8.417,'--')
i14[n].fits[0].plot_select('r','k',lw,-8.417,-6.98202)

for k in se14[n]:
    ax1.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-31,-6.98202)
plt.xticks([-30,-20,-10])

ax2 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,right_space:2*x_len+right_space+mid_space])
ax2.annotate('H', xy=(0.01, 0.88), xycoords="axes fraction")
n = 4
j = 1
plt.plot(d144[0],d144[1])
i14[n].fits[1].plot_select('l','k',lw,-31,-21.7726)
i14[n].fits[1].plot_select('l','k',lw,-21.7726,-17.7358,'--')

i14[n].fits[1].plot_select('r','r',lw,-31,-21.7726,'--')
i14[n].fits[1].plot_select('r','r',lw,-21.7726,-17.7358)

i14[n].fits[0].plot_select('l','r',lw,-17.7358,-14.4199)
i14[n].fits[0].plot_select('l','r',lw,-14.4199,-7.19,'--')

i14[n].fits[0].plot_select('r','#00ff00',lw,-17.7358,-14.4199,'--')
i14[n].fits[0].plot_select('r','#00ff00',lw,-14.4199,-7.19)

for k in se14[n]:
    ax2.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-31,-7.19)
plt.xticks([-30,-20,-10])

ax3 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,right_space:2*x_len+right_space+mid_space])
ax3.annotate('I', xy=(0.01, 0.88), xycoords="axes fraction")
n = 5
soft = Analysis.Run(np.load('2011_Raw.npy'), np.load('2011_Prune_new_flat.npy'), Analysis.bval2011, np.load('2011bf_new_prune_flat_edit.npy')).prune_data
init_plot(soft[n])
i11[n].fits[1].plot_select('l','k',lw,-44,-35.2168)
i11[n].fits[1].plot_select('l','k',lw,-35.2168,-32.76,'--')

i11[n].fits[1].plot_select('r','r',lw,-44,-35.2168,'--')
i11[n].fits[1].plot_select('r','r',lw,-35.2168,-34.0052)

i11[n].fits[0].plot_select('l','r',lw,-34.0052,-30.2804)
i11[n].fits[0].plot_select('l','r',lw,-30.2804,-10,'--')

i11[n].fits[0].plot_select('r','#00ff00',lw,-34.0052,-30.2804,'--')
i11[n].fits[0].plot_select('r','#00ff00',lw,-30.2804,-10)

for k in se11[n]:
    ax3.axvline(k[0],color='k',lw=2)

set_axis(i11[n],-43.2812,-21.5518)
plt.xticks([-40,-30])

#PI-----------------------------------------------------------------

ax4 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax4.annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")
n = 9
j = 1
plt.plot(d149[0],d149[1])
i14[n].fits[j].plot_select('l','k',lw,-19.8524,-13.9762)
i14[n].fits[j].plot_select('l','k',lw,-13.9762,-6.437,'--')
i14[n].fits[j].plot_select('r','r',lw,-13.9762,-6.437)
i14[n].fits[j].plot_select('r','r',lw,-19.8524,-13.9762,'--')
ax4.axvline(-13.7033,color='k',lw=2)
set_axis(i14[n],-19.8524,-8)
plt.xticks([-15,-10])

ax5 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax5.annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
n = 8
j = 0
init_plot(i11[n])
i11[n].fits[j].plot_select('l','k',lw,-40.4377,-35.138)
i11[n].fits[j].plot_select('l','k',lw,-35.138,-34.0386,'--')
i11[n].fits[j].plot_select('l','k',lw,-34.0386,-33.4822)
i11[n].fits[j].plot_select('l','k',lw,-33.4822,-30.6139,'--')
i11[n].fits[j].plot_select('r','r',lw,-40.4377,-35.138,'--')
i11[n].fits[j].plot_select('r','r',lw,-35.138,-34.0386)
i11[n].fits[j].plot_select('r','r',lw,-34.0386,-33.4822,'--')
i11[n].fits[j].plot_select('r','r',lw,-33.4822,-30.6139)

for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
    ax5.axvline(k[0],color='k',lw=2)
set_axis(i11[n],-40.4377,-30.6139)
plt.xticks([-40,-35])

ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax6.annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")
n = 14
j = 1
init_plot(i11[n])
i11[n].fits[j].plot_select('l','k',lw,-41.6623,-34.0011)
i11[n].fits[j].plot_select('l','k',lw,-34.0011,-30.424,'--')
i11[n].fits[j].plot_select('r','r',lw,-41.6623,-34.0011,'--')
i11[n].fits[j].plot_select('r','r',lw,-34.0011,-30.424)
for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
    ax6.axvline(k[0],color='k',lw=2)
set_axis(i11[n],-41.6623,-30.424)
plt.xticks([-40,-35])

#PI/4-----------------------------------------------------------------------------

ax7 = plt.subplot(gs[:y_len,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax7.annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")
n = 2
j = 2
init_plot(i14[n])
i14[n].fits[2].plot_select('l','k',lw,-21.4367,-19.6676)
i14[n].fits[2].plot_select('l','k',lw,-19.6676,-13.76,'--')

i14[n].fits[2].plot_select('r','r',lw,-21.4367,-19.6676,'--')
i14[n].fits[2].plot_select('r','r',lw,-19.6676,-18.6335)
i14[n].fits[2].plot_select('r','r',lw,-18.6335,-18.223,'--')
i14[n].fits[2].plot_select('r','r',lw,-18.223,-17.8369)
i14[n].fits[1].plot_select('l','r',lw,-17.8369,-17.7601)
i14[n].fits[1].plot_select('l','r',lw,-17.7601,-17.4343,'--')
i14[n].fits[1].plot_select('l','r',lw,-17.343,-13.76)

i14[n].fits[1].plot_select('r','#00ff00',lw,-21.4367,-18.6335,'--')
i14[n].fits[1].plot_select('r','#00ff00',lw,-18.6335,-18.223)
i14[n].fits[1].plot_select('r','#00ff00',lw,-18.223,-17.7601,'--')
i14[n].fits[1].plot_select('r','#00ff00',lw,-17.7601,-17.4343)
i14[n].fits[1].plot_select('r','#00ff00',lw,-17.343,-13.76,'--')

for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[j].delta_phi)<0.01]:
    ax7.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-21.4367,-13.76)
plt.xticks([-20,-15])

ax8 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax8.annotate('E', xy=(0.01, 0.88), xycoords="axes fraction")
n = 7
j = 2
init_plot(i14[n])
i14[n].fits[j].plot_select('l','k',lw,-27.85,-21.9669)
i14[n].fits[j].plot_select('l','k',lw,-21.9669,-21.0443,'--')
i14[n].fits[j].plot_select('l','k',lw,-21.0443,-19.47)

i14[n].fits[j].plot_select('r','r',lw,-27.85,-21.9669,'--')
i14[n].fits[j].plot_select('r','r',lw,-21.9669,-21.0443)
i14[n].fits[j].plot_select('r','r',lw,-21.0443,-19.47,'--')

for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[j].delta_phi)<0.01]:
    ax8.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-27.85,-19.47)
plt.xticks([-25,-20])

ax9 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax9.annotate('F', xy=(0.01, 0.88), xycoords="axes fraction")
n = 19
j = 1
init_plot(soft[n])
i11[n].fits[j].plot_select('l','k',lw,-35.0326,-31.5792)
i11[n].fits[j].plot_select('l','k',lw,-31.5792,-25.2446,'--')

i11[n].fits[j].plot_select('r','r',lw,-35.0326,-31.5792,'--')
i11[n].fits[j].plot_select('r','r',lw,-31.5792,-25.2446)

for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
    ax9.axvline(k[0],color='k',lw=2)

set_axis(i11[n],-35.0326,-25.2446)
plt.xticks([-35,-30])

ax1.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax1.yaxis.set_label_coords(-.05, 1.1)

ax3.set_xlabel('V$_{P}$ (mV)',size=12)
#ax9.xaxis.set_label_coords(-0.05, -0.1)

# %%
fig.savefig('All Fit v2_5',dpi=1200)

# %%
#Full and windows v3 - Kang Picks v1
mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[7.2,7.2*1.2])
gs = GridSpec(1000,1000)
num_y = 6
num_x = 2
right_space = 0
mid_space = 60
bot_space = 25
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
lw = 3
#-------------------------------------------------------------------------------
#Altered pruned data:
soft11 = Analysis.Run(np.load('2011_Raw.npy'), np.load('2011_Prune_new_flat.npy'), Analysis.bval2011, np.load('2011bf_new_prune_flat_edit.npy')).prune_data
soft14 = Analysis.Run(np.load('2014_Raw.npy'), np.load('2014_Prune_new.npy'), Analysis.bval2011, np.load('2014bf_new_prune_edit.npy')).prune_data
d140 = np.load('2014_0.npy')
d144 = np.load('2014_4.npy')
d149 = np.load('2014_9.npy')
d110 = np.load('2011_0.npy')

se11 = np.load('2011se_flat_edit.npy')
se14 = np.load('2014se_edit.npy')

#-------------------------------------------------------------------------------
ax1 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:2*x_len+right_space+mid_space])
ax1.annotate('G', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 3
plt.plot(d140[0],d140[1])
i14[n].fits[3].plot_select('l','k',lw,-31,-22.1535)
i14[n].fits[3].plot_select('l','k',lw,-22.1535,-19.8804,'--')

i14[n].fits[3].plot_select('r','r',lw,-31,-22.1535,'--')
i14[n].fits[3].plot_select('r','r',lw,-22.1535,-19.8804)

i14[n].fits[2].plot_select('l','r',lw,-19.8804,-19.4419)
i14[n].fits[2].plot_select('l','r',lw,-19.4419,-19.0109,'--')

i14[n].fits[2].plot_select('r','#00ff00',lw,-20.99,-19.4419,'--')
i14[n].fits[2].plot_select('r','#00ff00',lw,-19.4419,-18.675)
i14[n].fits[1].plot_select('l','#00ff00',lw,-18.675,-14.87)
i14[n].fits[1].plot_select('l','#00ff00',lw,-14.87,-10.93,'--')

i14[n].fits[1].plot_select('r','orange',lw,-18.675,-14.87,'--')
i14[n].fits[1].plot_select('r','orange',lw,-14.87,-11.7825)
i14[n].fits[0].plot_select('l','orange',lw,-11.7825,-8.417)
i14[n].fits[0].plot_select('l','orange',lw,-8.417,-6.98202,'--')

i14[n].fits[0].plot_select('r','k',lw,-10.8774,-8.417,'--')
i14[n].fits[0].plot_select('r','k',lw,-8.417,-6.98202)

for k in se14[n]:
    ax1.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-31,-6.98202)
plt.xticks([-30,-20,-10])

ax2 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,right_space:2*x_len+right_space+mid_space])
ax2.annotate('H', xy=(0.01, 0.88), xycoords="axes fraction")
n = 4
j = 1
plt.plot(d144[0],d144[1])
i14[n].fits[1].plot_select('l','k',lw,-31,-21.7726)
i14[n].fits[1].plot_select('l','k',lw,-21.7726,-17.7358,'--')

i14[n].fits[1].plot_select('r','r',lw,-31,-21.7726,'--')
i14[n].fits[1].plot_select('r','r',lw,-21.7726,-17.7358)

i14[n].fits[0].plot_select('l','r',lw,-17.7358,-14.4199)
i14[n].fits[0].plot_select('l','r',lw,-14.4199,-7.19,'--')

i14[n].fits[0].plot_select('r','#00ff00',lw,-17.7358,-14.4199,'--')
i14[n].fits[0].plot_select('r','#00ff00',lw,-14.4199,-7.19)

for k in se14[n]:
    ax2.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-31,-7.19)
plt.xticks([-30,-20,-10])


ax3 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,right_space:2*x_len+right_space+mid_space])
ax3.annotate('I', xy=(0.01, 0.88), xycoords="axes fraction")
n = 5
soft = Analysis.Run(np.load('2011_Raw.npy'), np.load('2011_Prune_new_flat.npy'), Analysis.bval2011, np.load('2011bf_new_prune_flat_edit.npy')).prune_data
init_plot(soft[n])
i11[n].fits[1].plot_select('l','k',lw,-44,-35.2168)
i11[n].fits[1].plot_select('l','k',lw,-35.2168,-32.76,'--')

i11[n].fits[1].plot_select('r','r',lw,-44,-35.2168,'--')
i11[n].fits[1].plot_select('r','r',lw,-35.2168,-34.0052)

i11[n].fits[0].plot_select('l','r',lw,-34.0052,-30.2804)
i11[n].fits[0].plot_select('l','r',lw,-30.2804,-10,'--')

i11[n].fits[0].plot_select('r','#00ff00',lw,-34.0052,-30.2804,'--')
i11[n].fits[0].plot_select('r','#00ff00',lw,-30.2804,-10)

for k in se11[n]:
    ax3.axvline(k[0],color='k',lw=2)

set_axis(i11[n],-43.2812,-21.5518)
plt.xticks([-40,-30])


#PI--------------------------------------------------------------------


ax4 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax4.annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")
n = 7
j = 1
init_plot(soft14[n])
i14[n].fits[j].plot_select('l','k',lw,-21.02,-14.17)
i14[n].fits[j].plot_select('l','k',lw,-14.17,-10.565,'--')

i14[n].fits[j].plot_select('r','r',lw,-21.02,-14.17,'--')
i14[n].fits[j].plot_select('r','r',lw,-14.17,-10.565)
set_axis(i14[n],-21.02,-10.565)
ax4.axvline(-14.17,color='k',lw=2)
plt.xticks([-20,-15])

ax5 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax5.annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
n = 1
j = 0
init_plot(soft11[n])
i11[n].fits[j].plot_select('l','k',lw,-26.3665,-20.087)
i11[n].fits[j].plot_select('l','k',lw,-20.087,-17.45,'--')

i11[n].fits[j].plot_select('r','r',lw,-26.3665,-20.087,'--')
i11[n].fits[j].plot_select('r','r',lw,-20.087,-17.45)
set_axis(i11[n],-26.3665,-17.45)
plt.ylim([11.35,11.89])
plt.xticks([-25,-20])

for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
    ax5.axvline(k[0],color='k',lw=2)


ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax6.annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")
n = 3
j = 0
init_plot(soft11[n])
i11[n].fits[j].plot_select('l','k',lw,-40.7668,-35.4962)
i11[n].fits[j].plot_select('l','k',lw,-35.4962,-29.9666,'--')

i11[n].fits[j].plot_select('r','r',lw,-40.7668,-35.4962,'--')
i11[n].fits[j].plot_select('r','r',lw,-35.4962,-29.9666)
set_axis(i11[n],-40.7668,-29.9666)
plt.xticks([-40,-35])

for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
    ax6.axvline(k[0],color='k',lw=2)




#PI/4--------------------------------------------------------------------


ax7 = plt.subplot(gs[:y_len,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax7.annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")
n = 3
j = 3
init_plot(i14[n])
i14[n].fits[4].plot_select('l','k',lw,-26.8855,-21.615)
i14[n].fits[4].plot_select('l','k',lw,-21.615,-18.41,'--')

i14[n].fits[4].plot_select('r','r',lw,-26.8855,-21.615,'--')
i14[n].fits[3].plot_select('l','r',lw,-21.615,-20.2475)
i14[n].fits[3].plot_select('l','r',lw,-20.2475,-18.41,'--')

i14[n].fits[3].plot_select('r','#00ff00',lw,-26.8855,-20.2475,'--')
i14[n].fits[3].plot_select('r','#00ff00',lw,-20.2475,-18.41)
set_axis(i14[n],-26.8855,-19.0156)

ax7.axvline(-20.2475,color='k',lw=2)
for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[4].delta_phi)<0.01]:
    ax7.axvline(k[0],color='k',lw=2)
plt.xticks([-25,-20])


ax8 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax8.annotate('E', xy=(0.01, 0.88), xycoords="axes fraction")
n = 7
j = 2
init_plot(i14[n])
i14[n].fits[j].plot_select('l','k',lw,-27.85,-21.9669)
i14[n].fits[j].plot_select('l','k',lw,-21.9669,-21.0443,'--')
i14[n].fits[j].plot_select('l','k',lw,-21.0443,-19.47)

i14[n].fits[j].plot_select('r','r',lw,-27.85,-21.9669,'--')
i14[n].fits[j].plot_select('r','r',lw,-21.9669,-21.0443)
i14[n].fits[j].plot_select('r','r',lw,-21.0443,-19.47,'--')

for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[j].delta_phi)<0.01]:
    ax8.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-27.85,-19.47)
plt.xticks([-25,-20])

ax9 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax9.annotate('F', xy=(0.01, 0.88), xycoords="axes fraction")
n = 8
j = 3
init_plot(i14[n])
i14[n].fits[0].plot_select('l','k',lw,-32,-30.976)
i14[n].fits[0].plot_select('l','k',lw,-30.976,-30.0459,'--')
i14[n].fits[0].plot_select('l','k',lw,-30.0459,-28.8628)
i14[n].fits[0].plot_select('l','k',lw,-28.8628,-27.5768,'--')
i14[n].fits[0].plot_select('l','k',lw,-27.5768,-26.6205)
i14[n].fits[0].plot_select('l','k',lw,-26.6205,-23,'--')

i14[n].fits[0].plot_select('r','r',lw,-32,-30.976,'--')
i14[n].fits[0].plot_select('r','r',lw,-30.976,-30.0459)
i14[n].fits[0].plot_select('r','r',lw,-30.0459,-28.8628,'--')
i14[n].fits[0].plot_select('r','r',lw,-28.8628,-27.5768)
i14[n].fits[0].plot_select('r','r',lw,-27.5768,-26.6205,'--')
i14[n].fits[0].plot_select('r','r',lw,-26.6205,-23)

set_axis(i14[n],-31.0698,-23)
plt.xticks([-30,-25])
ax9.axvline(-30.9761,color='k',lw=2)
for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[3].delta_phi)<0.01]:
    ax9.axvline(k[0],color='k',lw=2)
for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[0].delta_phi)<0.01]:
    ax9.axvline(k[0],color='k',lw=2)



ax1.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax1.yaxis.set_label_coords(-.05, 1.1)

ax3.set_xlabel('V$_{P}$ (mV)',size=12)
#ax9.xaxis.set_label_coords(-0.05, -0.1)

# %%
fig.savefig('All Fit v3',dpi=1200) #Kang Choices

# %%
#Full and windows v3 - Kang Picks v2
mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[7.2,7.2*1.2])
gs = GridSpec(1000,1000)
num_y = 6
num_x = 2
right_space = 0
mid_space = 60
bot_space = 25
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
lw = 3
#-------------------------------------------------------------------------------
#Altered pruned data:
soft11 = Analysis.Run(np.load('2011_Raw.npy'), np.load('2011_Prune_new_flat.npy'), Analysis.bval2011, np.load('2011bf_new_prune_flat_edit.npy')).prune_data
soft14 = Analysis.Run(np.load('2014_Raw.npy'), np.load('2014_Prune_new.npy'), Analysis.bval2011, np.load('2014bf_new_prune_edit.npy')).prune_data
d140 = np.load('2014_0.npy')
d144 = np.load('2014_4.npy')
d149 = np.load('2014_9.npy')
d110 = np.load('2011_0.npy')

se11 = np.load('2011se_flat_edit.npy')
se14 = np.load('2014se_edit.npy')

#-------------------------------------------------------------------------------
ax1 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:2*x_len+right_space+mid_space])
ax1.annotate('G', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 3
plt.plot(d140[0],d140[1])
i14[n].fits[3].plot_select('l','k',lw,-31,-22.1535)
i14[n].fits[3].plot_select('l','k',lw,-22.1535,-19.8804,'--')

i14[n].fits[3].plot_select('r','r',lw,-31,-22.1535,'--')
i14[n].fits[3].plot_select('r','r',lw,-22.1535,-19.8804)

i14[n].fits[2].plot_select('l','r',lw,-19.8804,-19.4419)
i14[n].fits[2].plot_select('l','r',lw,-19.4419,-19.0109,'--')

i14[n].fits[2].plot_select('r','#00ff00',lw,-20.99,-19.4419,'--')
i14[n].fits[2].plot_select('r','#00ff00',lw,-19.4419,-18.675)
i14[n].fits[1].plot_select('l','#00ff00',lw,-18.675,-14.87)
i14[n].fits[1].plot_select('l','#00ff00',lw,-14.87,-10.93,'--')

i14[n].fits[1].plot_select('r','orange',lw,-18.675,-14.87,'--')
i14[n].fits[1].plot_select('r','orange',lw,-14.87,-11.7825)
i14[n].fits[0].plot_select('l','orange',lw,-11.7825,-8.417)
i14[n].fits[0].plot_select('l','orange',lw,-8.417,-6.98202,'--')

i14[n].fits[0].plot_select('r','k',lw,-10.8774,-8.417,'--')
i14[n].fits[0].plot_select('r','k',lw,-8.417,-6.98202)

for k in se14[n]:
    ax1.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-31,-6.98202)
plt.xticks([-30,-20,-10])

ax2 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,right_space:2*x_len+right_space+mid_space])
ax2.annotate('H', xy=(0.01, 0.88), xycoords="axes fraction")
n = 4
j = 1
plt.plot(d144[0],d144[1])
i14[n].fits[1].plot_select('l','k',lw,-31,-21.7726)
i14[n].fits[1].plot_select('l','k',lw,-21.7726,-17.7358,'--')

i14[n].fits[1].plot_select('r','r',lw,-31,-21.7726,'--')
i14[n].fits[1].plot_select('r','r',lw,-21.7726,-17.7358)

i14[n].fits[0].plot_select('l','r',lw,-17.7358,-14.4199)
i14[n].fits[0].plot_select('l','r',lw,-14.4199,-7.19,'--')

i14[n].fits[0].plot_select('r','#00ff00',lw,-17.7358,-14.4199,'--')
i14[n].fits[0].plot_select('r','#00ff00',lw,-14.4199,-7.19)

for k in se14[n]:
    ax2.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-31,-7.19)
plt.xticks([-30,-20,-10])


ax3 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,right_space:2*x_len+right_space+mid_space])
ax3.annotate('I', xy=(0.01, 0.88), xycoords="axes fraction")
n = 5
soft = Analysis.Run(np.load('2011_Raw.npy'), np.load('2011_Prune_new_flat.npy'), Analysis.bval2011, np.load('2011bf_new_prune_flat_edit.npy')).prune_data
init_plot(soft[n])
i11[n].fits[1].plot_select('l','k',lw,-44,-35.2168)
i11[n].fits[1].plot_select('l','k',lw,-35.2168,-32.76,'--')

i11[n].fits[1].plot_select('r','r',lw,-44,-35.2168,'--')
i11[n].fits[1].plot_select('r','r',lw,-35.2168,-34.0052)

i11[n].fits[0].plot_select('l','r',lw,-34.0052,-30.2804)
i11[n].fits[0].plot_select('l','r',lw,-30.2804,-10,'--')

i11[n].fits[0].plot_select('r','#00ff00',lw,-34.0052,-30.2804,'--')
i11[n].fits[0].plot_select('r','#00ff00',lw,-30.2804,-10)

for k in se11[n]:
    ax3.axvline(k[0],color='k',lw=2)

set_axis(i11[n],-43.2812,-21.5518)
plt.xticks([-40,-30])


#PI--------------------------------------------------------------------


ax4 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax4.annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")
n = 6
j = 0
init_plot(soft11[n])
i11[n].fits[j].plot_select('l','k',lw,-45.2278,-35.6776)
i11[n].fits[j].plot_select('l','k',lw,-35.6776,-30.5427,'--')

i11[n].fits[j].plot_select('r','r',lw,-45.2278,-35.6776,'--')
i11[n].fits[j].plot_select('r','r',lw,-35.6776,-30.5427)
set_axis(i11[n],-42.174,-30.5427)
plt.xticks([-40,-35])

for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
    ax4.axvline(k[0],color='k',lw=2)


ax5 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax5.annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
n = 15
j = 1
init_plot(i11[n])

i11[n].fits[j].plot_select('l','k',lw,-42.7665,-34.0758)
i11[n].fits[j].plot_select('l','k',lw,-34.0758,-30.0193,'--')

i11[n].fits[j].plot_select('r','r',lw,-42.7665,-34.07587,'--')
i11[n].fits[j].plot_select('r','r',lw,-34.0758,-30.0193)

set_axis(i11[n],-42.7665,-30.307)
plt.xticks([-40,-35])

for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
    ax5.axvline(k[0],color='k',lw=2)


ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax6.annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")
n = 19
j = 2

init_plot(i11[n])
i11[n].fits[j].plot_select('l','k',lw,-41.1981,-35.3895)
i11[n].fits[j].plot_select('l','k',lw,-35.3895,-31.6231,'--')

i11[n].fits[j].plot_select('r','r',lw,-41.1981,-35.3895,'--')
i11[n].fits[j].plot_select('r','r',lw,-35.3895,-31.6231)
set_axis(i11[n],-41.1981,-31.6231)
plt.xticks([-40,-35])

for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
    ax6.axvline(k[0],color='k',lw=2)




#PI/4--------------------------------------------------------------------


ax7 = plt.subplot(gs[:y_len,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax7.annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")
n = 3
j = 3
init_plot(i14[n])
i14[n].fits[4].plot_select('l','k',lw,-26.8855,-21.615)
i14[n].fits[4].plot_select('l','k',lw,-21.615,-18.41,'--')

i14[n].fits[4].plot_select('r','r',lw,-26.8855,-21.615,'--')
i14[n].fits[3].plot_select('l','r',lw,-21.615,-20.2475)
i14[n].fits[3].plot_select('l','r',lw,-20.2475,-18.41,'--')

i14[n].fits[3].plot_select('r','#00ff00',lw,-26.8855,-20.2475,'--')
i14[n].fits[3].plot_select('r','#00ff00',lw,-20.2475,-18.41)
set_axis(i14[n],-26.8855,-19.0156)

ax7.axvline(-20.2475,color='k',lw=2)
for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[4].delta_phi)<0.01]:
    ax7.axvline(k[0],color='k',lw=2)


ax8 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax8.annotate('E', xy=(0.01, 0.88), xycoords="axes fraction")
n = 7
j = 2
init_plot(i14[n])
i14[n].fits[j].plot_select('l','k',lw,-27.85,-21.9669)
i14[n].fits[j].plot_select('l','k',lw,-21.9669,-21.0443,'--')
i14[n].fits[j].plot_select('l','k',lw,-21.0443,-19.47)

i14[n].fits[j].plot_select('r','r',lw,-27.85,-21.9669,'--')
i14[n].fits[j].plot_select('r','r',lw,-21.9669,-21.0443)
i14[n].fits[j].plot_select('r','r',lw,-21.0443,-19.47,'--')

for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[j].delta_phi)<0.01]:
    ax8.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-27.85,-19.47)
plt.xticks([-25,-20])

ax9 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax9.annotate('F', xy=(0.01, 0.88), xycoords="axes fraction")
n = 8
j = 3
init_plot(soft14[n])
i14[n].fits[j].plot_select('l','k',lw,-26.6205,-21.1292)
i14[n].fits[j].plot_select('l','k',lw,-21.1292,-19.5416,'--')
i14[n].fits[j].plot_select('l','k',lw,-19.5416,-19.1765)
i14[n].fits[j].plot_select('l','k',lw,-19.1765,-19.0655,'--')
i14[n].fits[j].plot_select('l','k',lw,-19.0655,-18.6069)
i14[n].fits[j].plot_select('l','k',lw,-18.6069,-18.3616,'--')

i14[n].fits[j].plot_select('r','r',lw,-26.6205,-21.1292,'--')
i14[n].fits[j].plot_select('r','r',lw,-21.1292,-19.5416)
i14[n].fits[j].plot_select('r','r',lw,-19.5416,-19.1765,'--')
i14[n].fits[j].plot_select('r','r',lw,-19.1765,-19.0655)
i14[n].fits[j].plot_select('r','r',lw,-19.0655,-18.6069,'--')
i14[n].fits[j].plot_select('r','r',lw,-18.6069,-18.3616)

set_axis(i14[n],-26.62058,-18.3616)

for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[j].delta_phi)<0.01]:
    plt.axvline(k[0],color='k',lw=2)
plt.xticks([-25,-20])


ax1.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax1.yaxis.set_label_coords(-.05, 1.1)

ax3.set_xlabel('V$_{P}$ (mV)',size=12)
#ax9.xaxis.set_label_coords(-0.05, -0.1)

# %%
fig.savefig('All Fit v4',dpi=1200) #Kang Choices

# %%
#Full and windows v2.5
mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[7.2,7.2*1.2])
gs = GridSpec(1000,1000)
num_y = 6
num_x = 2
right_space = 0
mid_space = 60
bot_space = 25
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
lw = 3
#-------------------------------------------------------------------------------
#Altered pruned data:
d140 = np.load('2014_0.npy')
d144 = np.load('2014_4.npy')
d149 = np.load('2014_9.npy')
d110 = np.load('2011_0.npy')

se11 = np.load('2011se_flat_edit.npy')
se14 = np.load('2014se_edit.npy')

#-------------------------------------------------------------------------------
ax1 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:2*x_len+right_space+mid_space])
ax1.annotate('G', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 3
plt.plot(d140[0],d140[1])
i14[n].fits[3].plot_select('l','k',lw,-31,-22.1535)
i14[n].fits[3].plot_select('l','k',lw,-22.1535,-19.8804,'--')

i14[n].fits[3].plot_select('r','r',lw,-31,-22.1535,'--')
i14[n].fits[3].plot_select('r','r',lw,-22.1535,-19.8804)

i14[n].fits[2].plot_select('l','r',lw,-19.8804,-19.4419)
i14[n].fits[2].plot_select('l','r',lw,-19.4419,-19.0109,'--')

i14[n].fits[2].plot_select('r','#00ff00',lw,-20.99,-19.4419,'--')
i14[n].fits[2].plot_select('r','#00ff00',lw,-19.4419,-18.675)
i14[n].fits[1].plot_select('l','#00ff00',lw,-18.675,-14.87)
i14[n].fits[1].plot_select('l','#00ff00',lw,-14.87,-10.93,'--')

i14[n].fits[1].plot_select('r','orange',lw,-18.675,-14.87,'--')
i14[n].fits[1].plot_select('r','orange',lw,-14.87,-11.7825)
i14[n].fits[0].plot_select('l','orange',lw,-11.7825,-8.417)
i14[n].fits[0].plot_select('l','orange',lw,-8.417,-6.98202,'--')

i14[n].fits[0].plot_select('r','k',lw,-10.8774,-8.417,'--')
i14[n].fits[0].plot_select('r','k',lw,-8.417,-6.98202)

for k in se14[n]:
    ax1.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-31,-6.98202)
plt.xticks([-30,-20,-10])

ax2 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,right_space:2*x_len+right_space+mid_space])
ax2.annotate('H', xy=(0.01, 0.88), xycoords="axes fraction")
n = 4
j = 1
plt.plot(d144[0],d144[1])
i14[n].fits[1].plot_select('l','k',lw,-31,-21.7726)
i14[n].fits[1].plot_select('l','k',lw,-21.7726,-17.7358,'--')

i14[n].fits[1].plot_select('r','r',lw,-31,-21.7726,'--')
i14[n].fits[1].plot_select('r','r',lw,-21.7726,-17.7358)

i14[n].fits[0].plot_select('l','r',lw,-17.7358,-14.4199)
i14[n].fits[0].plot_select('l','r',lw,-14.4199,-7.19,'--')

i14[n].fits[0].plot_select('r','#00ff00',lw,-17.7358,-14.4199,'--')
i14[n].fits[0].plot_select('r','#00ff00',lw,-14.4199,-7.19)

for k in se14[n]:
    ax2.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-31,-7.19)
plt.xticks([-30,-20,-10])

ax3 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,right_space:2*x_len+right_space+mid_space])
ax3.annotate('I', xy=(0.01, 0.88), xycoords="axes fraction")
n = 5
soft = Analysis.Run(np.load('2011_Raw.npy'), np.load('2011_Prune_new_flat.npy'), Analysis.bval2011, np.load('2011bf_new_prune_flat_edit.npy')).prune_data
init_plot(soft[n])
i11[n].fits[1].plot_select('l','k',lw,-44,-35.2168)
i11[n].fits[1].plot_select('l','k',lw,-35.2168,-32.76,'--')

i11[n].fits[1].plot_select('r','r',lw,-44,-35.2168,'--')
i11[n].fits[1].plot_select('r','r',lw,-35.2168,-34.0052)

i11[n].fits[0].plot_select('l','r',lw,-34.0052,-30.2804)
i11[n].fits[0].plot_select('l','r',lw,-30.2804,-10,'--')

i11[n].fits[0].plot_select('r','#00ff00',lw,-34.0052,-30.2804,'--')
i11[n].fits[0].plot_select('r','#00ff00',lw,-30.2804,-10)

for k in se11[n]:
    ax3.axvline(k[0],color='k',lw=2)

set_axis(i11[n],-43.2812,-21.5518)
plt.xticks([-40,-30])

#PI--------------------------------------------

ax4 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax4.annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")
n = 9
j = 1
plt.plot(d149[0],d149[1])
i14[n].fits[j].plot_select('l','k',lw,-19.8524,-13.9762)
i14[n].fits[j].plot_select('l','k',lw,-13.9762,-6.437,'--')
i14[n].fits[j].plot_select('r','r',lw,-13.9762,-6.437)
i14[n].fits[j].plot_select('r','r',lw,-19.8524,-13.9762,'--')
ax4.axvline(-13.7033,color='k',lw=2)
set_axis(i14[n],-19.8524,-8)
plt.xticks([-15,-10])

ax5 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax5.annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 1
init_plot(i11[n])

i11[n].fits[j].plot_select('l','k',lw,-42.9385,-37.5519)
i11[n].fits[j].plot_select('l','k',lw,-37.5519,-37.1954,'--')
i11[n].fits[j].plot_select('l','k',lw,-37.1954,-36.8603)
i11[n].fits[j].plot_select('l','k',lw,-36.8603,-36.4394,'--')
i11[n].fits[j].plot_select('l','k',lw,-36.4394,-36.143)
i11[n].fits[j].plot_select('l','k',lw,-36.143,-30.0926,'--')

i11[n].fits[j].plot_select('r','r',lw,-42.9385,-37.5519,'--')
i11[n].fits[j].plot_select('r','r',lw,-37.5519,-37.1954)
i11[n].fits[j].plot_select('r','r',lw,-37.1954,-36.8603,'--')
i11[n].fits[j].plot_select('r','r',lw,-36.8603,-36.4394)
i11[n].fits[j].plot_select('r','r',lw,-36.4394,-36.143,'--')
i11[n].fits[j].plot_select('r','r',lw,-36.143,-30.0926)

set_axis(i11[n],-42.9385,-30.0926)

plt.xticks([-40,-35])


for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
    ax5.axvline(k[0],color='k',lw=2)

ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax6.annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")
n = 14
j = 1
init_plot(i11[n])
i11[n].fits[j].plot_select('l','k',lw,-41.6623,-34.0011)
i11[n].fits[j].plot_select('l','k',lw,-34.0011,-30.424,'--')
i11[n].fits[j].plot_select('r','r',lw,-41.6623,-34.0011,'--')
i11[n].fits[j].plot_select('r','r',lw,-34.0011,-30.424)
for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
    ax6.axvline(k[0],color='k',lw=2)
set_axis(i11[n],-41.6623,-30.424)
plt.xticks([-40,-35])

#PI/4---------------------------------------------------

ax7 = plt.subplot(gs[:y_len,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax7.annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")
n = 2
j = 2
init_plot(i14[n])
i14[n].fits[2].plot_select('l','k',lw,-21.4367,-19.6676)
i14[n].fits[2].plot_select('l','k',lw,-19.6676,-13.76,'--')

i14[n].fits[2].plot_select('r','r',lw,-21.4367,-19.6676,'--')
i14[n].fits[2].plot_select('r','r',lw,-19.6676,-18.6335)
i14[n].fits[2].plot_select('r','r',lw,-18.6335,-18.223,'--')
i14[n].fits[2].plot_select('r','r',lw,-18.223,-17.8369)
i14[n].fits[1].plot_select('l','r',lw,-17.8369,-17.7601)
i14[n].fits[1].plot_select('l','r',lw,-17.7601,-17.4343,'--')
i14[n].fits[1].plot_select('l','r',lw,-17.343,-13.76)

i14[n].fits[1].plot_select('r','#00ff00',lw,-21.4367,-18.6335,'--')
i14[n].fits[1].plot_select('r','#00ff00',lw,-18.6335,-18.223)
i14[n].fits[1].plot_select('r','#00ff00',lw,-18.223,-17.7601,'--')
i14[n].fits[1].plot_select('r','#00ff00',lw,-17.7601,-17.4343)
i14[n].fits[1].plot_select('r','#00ff00',lw,-17.343,-13.76,'--')

for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[j].delta_phi)<0.01]:
    ax7.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-21.4367,-13.76)
plt.xticks([-20,-15])

ax8 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax8.annotate('E', xy=(0.01, 0.88), xycoords="axes fraction")
n = 7
j = 2
init_plot(i14[n])
i14[n].fits[j].plot_select('l','k',lw,-27.85,-21.9669)
i14[n].fits[j].plot_select('l','k',lw,-21.9669,-21.0443,'--')
i14[n].fits[j].plot_select('l','k',lw,-21.0443,-19.47)

i14[n].fits[j].plot_select('r','r',lw,-27.85,-21.9669,'--')
i14[n].fits[j].plot_select('r','r',lw,-21.9669,-21.0443)
i14[n].fits[j].plot_select('r','r',lw,-21.0443,-19.47,'--')

for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[j].delta_phi)<0.01]:
    ax8.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-27.85,-19.47)
plt.xticks([-25,-20])

ax9 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax9.annotate('F', xy=(0.01, 0.88), xycoords="axes fraction")
n = 19
j = 1
init_plot(soft[n])
i11[n].fits[j].plot_select('l','k',lw,-35.0326,-31.5792)
i11[n].fits[j].plot_select('l','k',lw,-31.5792,-25.2446,'--')

i11[n].fits[j].plot_select('r','r',lw,-35.0326,-31.5792,'--')
i11[n].fits[j].plot_select('r','r',lw,-31.5792,-25.2446)

for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
    ax9.axvline(k[0],color='k',lw=2)

set_axis(i11[n],-35.0326,-25.2446)
plt.xticks([-35,-30])

ax1.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax1.yaxis.set_label_coords(-.05, 1.1)

ax3.set_xlabel('V$_{P}$ (mV)',size=12)
#ax9.xaxis.set_label_coords(-0.05, -0.1)

# %%
fig.savefig('All Fit v5',dpi=1200) #Kang Choices

# %%
def q_0():
    n = 2
    global j
    j = 2
    init_plot(i14[n])
    i14[n].fits[2].plot_select('l','k',lw,-21.4367,-19.6676)
    i14[n].fits[2].plot_select('l','k',lw,-19.6676,-13.76,'--')

    i14[n].fits[2].plot_select('r','r',lw,-21.4367,-19.6676,'--')
    i14[n].fits[2].plot_select('r','r',lw,-19.6676,-18.6335)
    i14[n].fits[2].plot_select('r','r',lw,-18.6335,-18.223,'--')
    i14[n].fits[2].plot_select('r','r',lw,-18.223,-17.8369)
    i14[n].fits[1].plot_select('l','r',lw,-17.8369,-17.7601)
    i14[n].fits[1].plot_select('l','r',lw,-17.7601,-17.4343,'--')
    i14[n].fits[1].plot_select('l','r',lw,-17.343,-13.76)

    i14[n].fits[1].plot_select('r','#00ff00',lw,-21.4367,-18.6335,'--')
    i14[n].fits[1].plot_select('r','#00ff00',lw,-18.6335,-18.223)
    i14[n].fits[1].plot_select('r','#00ff00',lw,-18.223,-17.7601,'--')
    i14[n].fits[1].plot_select('r','#00ff00',lw,-17.7601,-17.4343)
    i14[n].fits[1].plot_select('r','#00ff00',lw,-17.343,-13.76,'--')

    set_axis(i14[n],-21.4367,-13.76)
    plt.xticks([-20,-15])
    
    plt.axvline(-19.4858,color='k',lw=2)
    plt.axvline(-18.62333,color='k',lw=2)
    plt.axvline(-18.2212,color='k',lw=2)
    plt.axvline(-17.759945,color='k',lw=2)
    plt.axvline(-17.42249,color='k',lw=2)
        
def q_1():
    n = 3
    global j
    j = 3
    init_plot(i14[n])
    i14[n].fits[4].plot_select('l','k',lw,-26.8855,-21.615)
    i14[n].fits[4].plot_select('l','k',lw,-21.615,-18.41,'--')

    i14[n].fits[4].plot_select('r','r',lw,-26.8855,-21.615,'--')
    i14[n].fits[3].plot_select('l','r',lw,-21.615,-20.2475)
    i14[n].fits[3].plot_select('l','r',lw,-20.2475,-18.41,'--')

    i14[n].fits[3].plot_select('r','#00ff00',lw,-26.8855,-20.2475,'--')
    i14[n].fits[3].plot_select('r','#00ff00',lw,-20.2475,-18.41)
    
    set_axis(i14[n],-26.8855,-19.0156)
    plt.xticks([-25,-20])
    
    plt.axvline(-20.2475,color='k',lw=2)
    for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[4].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=2)
        
def q_2():
    n = 7
    global j
    j = 2
    init_plot(i14[n])
    i14[n].fits[j].plot_select('l','k',lw,-27.85,-21.9669)
    i14[n].fits[j].plot_select('l','k',lw,-21.9669,-21.0443,'--')
    i14[n].fits[j].plot_select('l','k',lw,-21.0443,-19.47)

    i14[n].fits[j].plot_select('r','r',lw,-27.85,-21.9669,'--')
    i14[n].fits[j].plot_select('r','r',lw,-21.9669,-21.0443)
    i14[n].fits[j].plot_select('r','r',lw,-21.0443,-19.47,'--')
    
    set_axis(i14[n],-27.85,-19.47)
    plt.xticks([-25,-20])
    
    for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[j].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=2)

def q_3():
    n = 8
    global j
    j = 3
    init_plot(i14[n])
    i14[n].fits[0].plot_select('l','k',lw,-32,-30.976)
    i14[n].fits[0].plot_select('l','k',lw,-30.976,-30.0459,'--')
    i14[n].fits[0].plot_select('l','k',lw,-30.0459,-28.8628)
    i14[n].fits[0].plot_select('l','k',lw,-28.8628,-27.5768,'--')
    i14[n].fits[0].plot_select('l','k',lw,-27.5768,-26.6205)
    i14[n].fits[0].plot_select('l','k',lw,-26.6205,-23,'--')

    i14[n].fits[0].plot_select('r','r',lw,-32,-30.976,'--')
    i14[n].fits[0].plot_select('r','r',lw,-30.976,-30.0459)
    i14[n].fits[0].plot_select('r','r',lw,-30.0459,-28.8628,'--')
    i14[n].fits[0].plot_select('r','r',lw,-28.8628,-27.5768)
    i14[n].fits[0].plot_select('r','r',lw,-27.5768,-26.6205,'--')
    i14[n].fits[0].plot_select('r','r',lw,-26.6205,-23)

    set_axis(i14[n],-31.0698,-23)
    plt.xticks([-30,-25])
    
    plt.axvline(-30.9761,color='k',lw=2)
    for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[3].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=2)
    for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[0].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=2)
        
def q_4():
    n = 8
    global j
    j = 3
    init_plot(soft14[n])
    i14[n].fits[j].plot_select('l','k',lw,-26.6205,-21.1292)
    i14[n].fits[j].plot_select('l','k',lw,-21.1292,-19.5416,'--')
    i14[n].fits[j].plot_select('l','k',lw,-19.5416,-19.1765)
    i14[n].fits[j].plot_select('l','k',lw,-19.1765,-19.0655,'--')
    i14[n].fits[j].plot_select('l','k',lw,-19.0655,-18.6069)
    i14[n].fits[j].plot_select('l','k',lw,-18.6069,-18.3616,'--')

    i14[n].fits[j].plot_select('r','r',lw,-26.6205,-21.1292,'--')
    i14[n].fits[j].plot_select('r','r',lw,-21.1292,-19.5416)
    i14[n].fits[j].plot_select('r','r',lw,-19.5416,-19.1765,'--')
    i14[n].fits[j].plot_select('r','r',lw,-19.1765,-19.0655)
    i14[n].fits[j].plot_select('r','r',lw,-19.0655,-18.6069,'--')
    i14[n].fits[j].plot_select('r','r',lw,-18.6069,-18.3616)

    set_axis(i14[n],-26.62058,-18.3616)
    plt.xticks([-25,-20])
    
    for k in se14[n][np.abs(se14[n][:,2] - i14[n].fits[j].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=2)
    
def q_5():
    n = 0
    global j
    j = 0
    d110 = np.load('2011_0.npy')
    plt.plot(d110[0],d110[1])
    
    i11[n].fits[j].plot_select('l','k',lw,-36.1293,-30.0753)
    i11[n].fits[j].plot_select('l','k',lw,-30.0753,-27.9345,'--')

    i11[n].fits[j].plot_select('r','r',lw,-36.1293,-30.0753,'--')
    i11[n].fits[j].plot_select('r','r',lw,-30.0753,-27.9345)

    set_axis(i11[n],-36.1293,-27.9345)
    plt.xticks([-35,-30])

    for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=2)
    
    
def q_6():
    n = 19
    global j
    j = 1
    init_plot(soft11[n])
    i11[n].fits[j].plot_select('l','k',lw,-35.0326,-31.5792)
    i11[n].fits[j].plot_select('l','k',lw,-31.5792,-25.2446,'--')

    i11[n].fits[j].plot_select('r','r',lw,-35.0326,-31.5792,'--')
    i11[n].fits[j].plot_select('r','r',lw,-31.5792,-25.2446)
    
    set_axis(i11[n],-35.0326,-25.2446)
    plt.xticks([-35,-30])
    
    for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=2)

# %%
axline = 2
def p_0():
    n = 7
    global j
    j = 1
    init_plot(soft14[n])
    i14[n].fits[j].plot_select('l','k',lw,-21.02,-14.17)
    i14[n].fits[j].plot_select('l','k',lw,-14.17,-10.565,'--')

    i14[n].fits[j].plot_select('r','r',lw,-21.02,-14.17,'--')
    i14[n].fits[j].plot_select('r','r',lw,-14.17,-10.565)
    
    set_axis(i14[n],-21.02,-10.565)
    plt.xticks([-20,-15])
    
    plt.axvline(-14.17,color='k',lw=axline)
    
def p_1():
    n = 9
    global j
    j = 1
    d149 = np.load('2014_9.npy')
    plt.plot(d149[0],d149[1])
    i14[n].fits[j].plot_select('l','k',lw,-19.8524,-13.9762)
    i14[n].fits[j].plot_select('l','k',lw,-13.9762,-6.437,'--')
    i14[n].fits[j].plot_select('r','r',lw,-13.9762,-6.437)
    i14[n].fits[j].plot_select('r','r',lw,-19.8524,-13.9762,'--')
    
    set_axis(i14[n],-19.8524,-8)
    plt.xticks([-15,-10])
    
    plt.axvline(-13.7033,color='k',lw=axline)
    
def p_2():
    n = 0
    global j
    j = 1
    init_plot(i11[n])

    i11[n].fits[j].plot_select('l','k',lw,-42.9385,-37.5519)
    i11[n].fits[j].plot_select('l','k',lw,-37.5519,-37.1954,'--')
    i11[n].fits[j].plot_select('l','k',lw,-37.1954,-36.8603)
    i11[n].fits[j].plot_select('l','k',lw,-36.8603,-36.4394,'--')
    i11[n].fits[j].plot_select('l','k',lw,-36.4394,-36.143)
    i11[n].fits[j].plot_select('l','k',lw,-36.143,-30.0926,'--')

    i11[n].fits[j].plot_select('r','r',lw,-42.9385,-37.5519,'--')
    i11[n].fits[j].plot_select('r','r',lw,-37.5519,-37.1954)
    i11[n].fits[j].plot_select('r','r',lw,-37.1954,-36.8603,'--')
    i11[n].fits[j].plot_select('r','r',lw,-36.8603,-36.4394)
    i11[n].fits[j].plot_select('r','r',lw,-36.4394,-36.143,'--')
    i11[n].fits[j].plot_select('r','r',lw,-36.143,-30.0926)

    set_axis(i11[n],-42.9385,-30.0926)
    plt.xticks([-40,-35])

    for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=axline)
        
def p_3():
    n = 1
    global j
    j = 0
    init_plot(soft11[n])
    i11[n].fits[j].plot_select('l','k',lw,-26.3665,-20.087)
    i11[n].fits[j].plot_select('l','k',lw,-20.087,-17.45,'--')

    i11[n].fits[j].plot_select('r','r',lw,-26.3665,-20.087,'--')
    i11[n].fits[j].plot_select('r','r',lw,-20.087,-17.45)
    
    set_axis(i11[n],-26.3665,-17.45)
    plt.ylim([11.35,11.89])
    plt.xticks([-25,-20])

    for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=axline)
                
def p_4():
    n = 3
    global j
    j = 0
    init_plot(soft11[n])
    i11[n].fits[j].plot_select('l','k',lw,-40.7668,-35.4962)
    i11[n].fits[j].plot_select('l','k',lw,-35.4962,-29.9666,'--')

    i11[n].fits[j].plot_select('r','r',lw,-40.7668,-35.4962,'--')
    i11[n].fits[j].plot_select('r','r',lw,-35.4962,-29.9666)
    set_axis(i11[n],-40.7668,-29.9666)
    plt.xticks([-40,-35])

    for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=axline)

def p_5():
    n = 6
    global j
    j = 0
    init_plot(soft11[n])
    i11[n].fits[j].plot_select('l','k',lw,-45.2278,-35.6776)
    i11[n].fits[j].plot_select('l','k',lw,-35.6776,-30.5427,'--')

    i11[n].fits[j].plot_select('r','r',lw,-45.2278,-35.6776,'--')
    i11[n].fits[j].plot_select('r','r',lw,-35.6776,-30.5427)
    
    set_axis(i11[n],-42.174,-30.5427)
    plt.xticks([-40,-35])

    for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=axline)

def p_6():
    n = 8
    global j 
    j = 0
    init_plot(i11[n])
    i11[n].fits[j].plot_select('l','k',lw,-40.4377,-35.138)
    i11[n].fits[j].plot_select('l','k',lw,-35.138,-34.0386,'--')
    i11[n].fits[j].plot_select('l','k',lw,-34.0386,-33.4822)
    i11[n].fits[j].plot_select('l','k',lw,-33.4822,-30.6139,'--')
    i11[n].fits[j].plot_select('r','r',lw,-40.4377,-35.138,'--')
    i11[n].fits[j].plot_select('r','r',lw,-35.138,-34.0386)
    i11[n].fits[j].plot_select('r','r',lw,-34.0386,-33.4822,'--')
    i11[n].fits[j].plot_select('r','r',lw,-33.4822,-30.6139)
    
    set_axis(i11[n],-40.4377,-30.6139)
    plt.xticks([-40,-35])
    
    for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=axline)
    

def p_7():
    n = 14
    global j 
    j = 1
    init_plot(i11[n])
    i11[n].fits[j].plot_select('l','k',lw,-41.6623,-34.0011)
    i11[n].fits[j].plot_select('l','k',lw,-34.0011,-30.424,'--')
    i11[n].fits[j].plot_select('r','r',lw,-41.6623,-34.0011,'--')
    i11[n].fits[j].plot_select('r','r',lw,-34.0011,-30.424)
    
    set_axis(i11[n],-41.6623,-30.424)
    plt.xticks([-40,-35])
    
    for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=axline)

        
def p_8():
    n = 15
    global j 
    j = 1
    init_plot(i11[n])

    i11[n].fits[j].plot_select('l','k',lw,-42.7665,-34.0758)
    i11[n].fits[j].plot_select('l','k',lw,-34.0758,-30.0193,'--')

    i11[n].fits[j].plot_select('r','r',lw,-42.7665,-34.07587,'--')
    i11[n].fits[j].plot_select('r','r',lw,-34.0758,-30.0193)

    set_axis(i11[n],-42.7665,-30.307)
    plt.xticks([-40,-35])

    for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=axline)


def p_9():
    n = 19
    global j 
    j = 2
    init_plot(i11[n])
    i11[n].fits[j].plot_select('l','k',lw,-41.1981,-35.3895)
    i11[n].fits[j].plot_select('l','k',lw,-35.3895,-31.6231,'--')

    i11[n].fits[j].plot_select('r','r',lw,-41.1981,-35.3895,'--')
    i11[n].fits[j].plot_select('r','r',lw,-35.3895,-31.6231)
    
    set_axis(i11[n],-41.1981,-31.6231)
    plt.xticks([-40,-35])

    for k in se11[n][np.abs(se11[n][:,2] - i11[n].fits[j].delta_phi)<0.01]:
        plt.axvline(k[0],color='k',lw=axline)

# %%
import os

dirpath = os.getcwd()

# %%
q = [q_0,q_1,q_2,q_3,q_4]# no 2011 events,q_5,q_6]
p = [p_0,p_1,p_2,p_4,p_5,p_6,p_7,p_8,p_9]

import itertools

q_perm = [perm for perm in itertools.combinations(q, 3)]
p_perm = [perm for perm in itertools.combinations(p, 3)]

# %%
counter = 0
find = 87
for q_plots in q_perm:
    for p_plots in p_perm:
        if counter == find:
            print(q_plots)
            print(p_plots)
        counter += 1
# Out:
# (<function q_0 at 0x00000000207759E8>, <function q_1 at 0x0000000020775BA8>, <function q_3 at 0x0000000020775B38>)
# (<function p_0 at 0x0000000020775588>, <function p_1 at 0x00000000207754A8>, <function p_6 at 0x00000000207755F8>)

# %%
#Base figure skeleton:

#Full and windows all permutations

mpl.rcParams.update({'font.size': 8})

counter = 0

gs = GridSpec(1000,1000)
num_y = 6
num_x = 2
right_space = 0
mid_space = 60
bot_space = 25
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
lw = 3

for q_plots in q_perm:
    for p_plots in p_perm:

        fig = plt.figure(figsize=[7.2,7.2*1.2])

        #-------------------------------------------------------------------------------
        ax1 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:2*x_len+right_space+mid_space])
        ax1.annotate('G', xy=(0.01, 0.88), xycoords="axes fraction")
        n = 0
        j = 3
        plt.plot(d140[0],d140[1])
        i14[n].fits[3].plot_select('l','k',lw,-31,-22.1535)
        i14[n].fits[3].plot_select('l','k',lw,-22.1535,-19.8804,'--')

        i14[n].fits[3].plot_select('r','r',lw,-31,-22.1535,'--')
        i14[n].fits[3].plot_select('r','r',lw,-22.1535,-19.8804)

        i14[n].fits[2].plot_select('l','r',lw,-19.8804,-19.4419)
        i14[n].fits[2].plot_select('l','r',lw,-19.4419,-19.0109,'--')

        i14[n].fits[2].plot_select('r','#00ff00',lw,-20.99,-19.4419,'--')
        i14[n].fits[2].plot_select('r','#00ff00',lw,-19.4419,-18.675)
        i14[n].fits[1].plot_select('l','#00ff00',lw,-18.675,-14.87)
        i14[n].fits[1].plot_select('l','#00ff00',lw,-14.87,-10.93,'--')

        i14[n].fits[1].plot_select('r','orange',lw,-18.675,-14.87,'--')
        i14[n].fits[1].plot_select('r','orange',lw,-14.87,-11.7825)
        i14[n].fits[0].plot_select('l','orange',lw,-11.7825,-8.417)
        i14[n].fits[0].plot_select('l','orange',lw,-8.417,-6.98202,'--')

        i14[n].fits[0].plot_select('r','k',lw,-10.8774,-8.417,'--')
        i14[n].fits[0].plot_select('r','k',lw,-8.417,-6.98202)

        for k in se14[n]:
            ax1.axvline(k[0],color='k',lw=1)

        set_axis(i14[n],-31,-6.98202)
        plt.xticks([-30,-20,-10])

        ax2 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,right_space:2*x_len+right_space+mid_space])
        ax2.annotate('H', xy=(0.01, 0.88), xycoords="axes fraction")
        n = 4
        j = 1
        plt.plot(d144[0],d144[1])
        i14[n].fits[1].plot_select('l','k',lw,-31,-21.7726)
        i14[n].fits[1].plot_select('l','k',lw,-21.7726,-17.7358,'--')

        i14[n].fits[1].plot_select('r','r',lw,-31,-21.7726,'--')
        i14[n].fits[1].plot_select('r','r',lw,-21.7726,-17.7358)

        i14[n].fits[0].plot_select('l','r',lw,-17.7358,-14.4199)
        i14[n].fits[0].plot_select('l','r',lw,-14.4199,-7.19,'--')

        i14[n].fits[0].plot_select('r','#00ff00',lw,-17.7358,-14.4199,'--')
        i14[n].fits[0].plot_select('r','#00ff00',lw,-14.4199,-7.19)

        for k in se14[n]:
            ax2.axvline(k[0],color='k',lw=1)

        set_axis(i14[n],-31,-7.19)
        plt.xticks([-30,-20,-10])

        ax3 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,right_space:2*x_len+right_space+mid_space])
        ax3.annotate('I', xy=(0.01, 0.88), xycoords="axes fraction")
        n = 5
        j = 1
        soft = Analysis.Run(np.load('2011_Raw.npy'), np.load('2011_Prune_new_flat.npy'), Analysis.bval2011, np.load('2011bf_new_prune_flat_edit.npy')).prune_data
        init_plot(soft[n])
        i11[n].fits[1].plot_select('l','k',lw,-44,-35.2168)
        i11[n].fits[1].plot_select('l','k',lw,-35.2168,-32.76,'--')

        i11[n].fits[1].plot_select('r','r',lw,-44,-35.2168,'--')
        i11[n].fits[1].plot_select('r','r',lw,-35.2168,-34.0052)

        i11[n].fits[0].plot_select('l','r',lw,-34.0052,-30.2804)
        i11[n].fits[0].plot_select('l','r',lw,-30.2804,-10,'--')

        i11[n].fits[0].plot_select('r','#00ff00',lw,-34.0052,-30.2804,'--')
        i11[n].fits[0].plot_select('r','#00ff00',lw,-30.2804,-10)

        for k in se11[n]:
            ax3.axvline(k[0],color='k',lw=1)

        set_axis(i11[n],-43.2812,-21.5518)
        plt.xticks([-40,-30])

        #PI--------------------------------------------

        ax4 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
        ax4.annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")
        p_plots[0]()

        ax5 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
        ax5.annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
        p_plots[1]()

        ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
        ax6.annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")
        p_plots[2]()

        #PI/4---------------------------------------------------

        ax7 = plt.subplot(gs[:y_len,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
        ax7.annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")
        q_plots[0]()

        ax8 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
        ax8.annotate('E', xy=(0.01, 0.88), xycoords="axes fraction")
        q_plots[1]()

        ax9 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
        ax9.annotate('F', xy=(0.01, 0.88), xycoords="axes fraction")
        q_plots[2]()

        ax1.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
        ax1.yaxis.set_label_coords(-.05, 1.1)

        ax3.set_xlabel('V$_{P}$ (mV)',size=12)
        
        fig.savefig(dirpath+'/Permutations/'+'Fig_Permutation_{}.png'.format(counter), format="PNG")

        plt.close(fig)
        counter += 1

# %%
#Base figure skeleton:

#Full and windows all permutations

mpl.rcParams.update({'font.size': 8})

gs = GridSpec(1000,1000)
num_y = 6
num_x = 2
right_space = 0
mid_space = 60
bot_space = 25
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
lw = 3

q_plots = q_perm[3]
p_plots = p_perm[31]

fig = plt.figure(figsize=[7.2,7.2*1.2])

#-------------------------------------------------------------------------------
ax1 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:2*x_len+right_space+mid_space])
ax1.annotate('G', xy=(0.01, 0.88), xycoords="axes fraction")
n = 0
j = 3
plt.plot(d140[0],d140[1])
i14[n].fits[3].plot_select('l','k',lw,-31,-22.1535)
i14[n].fits[3].plot_select('l','k',lw,-22.1535,-19.8804,'--')

i14[n].fits[3].plot_select('r','r',lw,-31,-22.1535,'--')
i14[n].fits[3].plot_select('r','r',lw,-22.1535,-19.8804)

i14[n].fits[2].plot_select('l','r',lw,-19.8804,-19.4419)
i14[n].fits[2].plot_select('l','r',lw,-19.4419,-19.0109,'--')

i14[n].fits[2].plot_select('r','#00ff00',lw,-20.99,-19.4419,'--')
i14[n].fits[2].plot_select('r','#00ff00',lw,-19.4419,-18.675)
i14[n].fits[1].plot_select('l','#00ff00',lw,-18.675,-14.87)
i14[n].fits[1].plot_select('l','#00ff00',lw,-14.87,-10.93,'--')

i14[n].fits[1].plot_select('r','orange',lw,-18.675,-14.87,'--')
i14[n].fits[1].plot_select('r','orange',lw,-14.87,-11.7825)
i14[n].fits[0].plot_select('l','orange',lw,-11.7825,-8.417)
i14[n].fits[0].plot_select('l','orange',lw,-8.417,-6.98202,'--')

i14[n].fits[0].plot_select('r','k',lw,-10.8774,-8.417,'--')
i14[n].fits[0].plot_select('r','k',lw,-8.417,-6.98202)

for k in se14[n]:
    ax1.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-31,-6.98202)
plt.xticks([-30,-20,-10])

ax2 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,right_space:2*x_len+right_space+mid_space])
ax2.annotate('H', xy=(0.01, 0.88), xycoords="axes fraction")
n = 4
j = 1
plt.plot(d144[0],d144[1])
i14[n].fits[1].plot_select('l','k',lw,-31,-21.7726)
i14[n].fits[1].plot_select('l','k',lw,-21.7726,-17.7358,'--')

i14[n].fits[1].plot_select('r','r',lw,-31,-21.7726,'--')
i14[n].fits[1].plot_select('r','r',lw,-21.7726,-17.7358)

i14[n].fits[0].plot_select('l','r',lw,-17.7358,-14.4199)
i14[n].fits[0].plot_select('l','r',lw,-14.4199,-7.19,'--')

i14[n].fits[0].plot_select('r','#00ff00',lw,-17.7358,-14.4199,'--')
i14[n].fits[0].plot_select('r','#00ff00',lw,-14.4199,-7.19)

for k in se14[n]:
    ax2.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-31,-7.19)
plt.xticks([-30,-20,-10])

ax3 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,right_space:2*x_len+right_space+mid_space])
ax3.annotate('I', xy=(0.01, 0.88), xycoords="axes fraction")
n = 5
j = 1
soft = Analysis.Run(np.load('2011_Raw.npy'), np.load('2011_Prune_new_flat.npy'), Analysis.bval2011, np.load('2011bf_new_prune_flat_edit.npy')).prune_data
init_plot(soft[n])
i11[n].fits[1].plot_select('l','k',lw,-44,-35.2168)
i11[n].fits[1].plot_select('l','k',lw,-35.2168,-32.76,'--')

i11[n].fits[1].plot_select('r','r',lw,-44,-35.2168,'--')
i11[n].fits[1].plot_select('r','r',lw,-35.2168,-34.0052)

i11[n].fits[0].plot_select('l','r',lw,-34.0052,-29.6798)
i11[n].fits[0].plot_select('l','r',lw,-29.6798,-10,'--')

i11[n].fits[0].plot_select('r','#00ff00',lw,-34.0052,-29.6798,'--')
i11[n].fits[0].plot_select('r','#00ff00',lw,-29.6798,-10)

for k in se11[n]:
    ax3.axvline(k[0],color='k',lw=2)

set_axis(i11[n],-43.2812,-21.5518)
plt.xticks([-40,-30])

#PI--------------------------------------------

ax4 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax4.annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")
p_plots[0]()

ax5 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax5.annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
p_plots[1]()

ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax6.annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")
p_plots[2]()

#PI/4---------------------------------------------------

ax7 = plt.subplot(gs[:y_len,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax7.annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")
q_plots[0]()

ax8 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax8.annotate('E', xy=(0.01, 0.88), xycoords="axes fraction")
q_plots[1]()

ax9 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax9.annotate('F', xy=(0.01, 0.88), xycoords="axes fraction")
q_plots[2]()

ax1.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax1.yaxis.set_label_coords(-.05, 1.1)

ax3.set_xlabel('V$_{P}$ (mV)',size=12)

# %%
fig.savefig('All Fit v6-Favorite',dpi=1200)

# %%
#Base figure skeleton:

#Full and windows all permutations

mpl.rcParams.update({'font.size': 8})

gs = GridSpec(1000,1000)
num_y = 6
num_x = 2
right_space = 0
mid_space = 60
bot_space = 25
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
lw = 3

q_plots = q_perm[3]
p_plots = p_perm[31]

fig = plt.figure(figsize=[7.2,7.2*1.2])


#PI--------------------------------------------

ax4 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax4.annotate('$\Delta\phi = {}\pi$'.format(round(2-i14[9].fits[1].delta_phi,2)), xy=(0.01, 0.88), xycoords="axes fraction")
p_plots[0]()

ax5 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax5.annotate('$\Delta\phi = {}\pi$'.format(round(2-i11[0].fits[1].delta_phi,2)), xy=(0.01, 0.88), xycoords="axes fraction")
p_plots[1]()

ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax6.annotate('$\Delta\phi = {}\pi$'.format(round(2-i11[14].fits[1].delta_phi,2)), xy=(0.01, 0.88), xycoords="axes fraction")
p_plots[2]()

#PI/4---------------------------------------------------

ax7 = plt.subplot(gs[:y_len,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax7.annotate('$\Delta\phi = {}\pi$'.format(round(2-i14[2].fits[2].delta_phi,2)), xy=(0.01, 0.88), xycoords="axes fraction")
q_plots[0]()

ax8 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax8.annotate('$\Delta\phi = {}\pi$'.format(round(2-i14[7].fits[2].delta_phi,2)), xy=(0.01, 0.88), xycoords="axes fraction")
q_plots[1]()

ax9 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax9.annotate('$\Delta\phi = {}\pi$'.format(round(2-i14[8].fits[3].delta_phi,2)), xy=(0.01, 0.88), xycoords="axes fraction")
q_plots[2]()

ax5.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
#

ax6.set_xlabel('V$_{P}$ (mV)',size=12)
ax6.xaxis.set_label_coords(1.05,-.2)

# %%
plt.savefig('Many Slips',dpi=1000)

# %%
#Base figure skeleton:

#Full and windows all permutations

mpl.rcParams.update({'font.size': 8, 'font.sans-serif':'Geneva'})

gs = GridSpec(1000,1000)
num_y = 6
num_x = 2
right_space = 0
mid_space = 60
bot_space = 25
y_len = int((1000-(num_y-1)*bot_space)/num_y)
x_len = int((1000-right_space-(num_x-1)*mid_space)/num_x)
ypad = 2
xpad = 4
lw = 3


fig = plt.figure(figsize=[7.2,7.2*1.2])

#-------------------------------------------------------------------------------
ax1 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:2*x_len+right_space+mid_space])
ax1.annotate('g', xy=(-0.025, 1.0), xycoords="axes fraction", weight='bold')
n = 0
j = 3
plt.plot(d140[0],d140[1])
i14[n].fits[3].plot_select('l','k',lw,-31,-22.1535)
i14[n].fits[3].plot_select('l','k',lw,-22.1535,-19.8804,'--')

i14[n].fits[3].plot_select('r','r',lw,-31,-22.1535,'--')
i14[n].fits[3].plot_select('r','r',lw,-22.1535,-19.8804)

i14[n].fits[2].plot_select('l','r',lw,-19.8804,-19.4419)
i14[n].fits[2].plot_select('l','r',lw,-19.4419,-19.0109,'--')

i14[n].fits[2].plot_select('r','#00ff00',lw,-20.99,-19.4419,'--')
i14[n].fits[2].plot_select('r','#00ff00',lw,-19.4419,-18.675)
i14[n].fits[1].plot_select('l','#00ff00',lw,-18.675,-14.87)
i14[n].fits[1].plot_select('l','#00ff00',lw,-14.87,-10.93,'--')

i14[n].fits[1].plot_select('r','orange',lw,-18.675,-14.87,'--')
i14[n].fits[1].plot_select('r','orange',lw,-14.87,-11.7825)
i14[n].fits[0].plot_select('l','orange',lw,-11.7825,-8.417)
i14[n].fits[0].plot_select('l','orange',lw,-8.417,-6.98202,'--')

i14[n].fits[0].plot_select('r','k',lw,-10.8774,-8.417,'--')
i14[n].fits[0].plot_select('r','k',lw,-8.417,-6.98202)

for k in se14[n]:
    ax1.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-31,-6.98202)
plt.xticks([-30,-20,-10])

ax2 = plt.subplot(gs[4*y_len+4*bot_space:5*y_len+4*bot_space,right_space:2*x_len+right_space+mid_space])
ax2.annotate('h', xy=(-0.025, 1.0), xycoords="axes fraction", weight='bold')
n = 4
j = 1
plt.plot(d144[0],d144[1])
i14[n].fits[1].plot_select('l','k',lw,-31,-21.7726)
i14[n].fits[1].plot_select('l','k',lw,-21.7726,-17.7358,'--')

i14[n].fits[1].plot_select('r','r',lw,-31,-21.7726,'--')
i14[n].fits[1].plot_select('r','r',lw,-21.7726,-17.7358)

i14[n].fits[0].plot_select('l','r',lw,-17.7358,-14.4199)
i14[n].fits[0].plot_select('l','r',lw,-14.4199,-7.19,'--')

i14[n].fits[0].plot_select('r','#00ff00',lw,-17.7358,-14.4199,'--')
i14[n].fits[0].plot_select('r','#00ff00',lw,-14.4199,-7.19)

for k in se14[n]:
    ax2.axvline(k[0],color='k',lw=2)

set_axis(i14[n],-31,-7.19)
plt.xticks([-30,-20,-10])

ax3 = plt.subplot(gs[5*y_len+5*bot_space:6*y_len+5*bot_space,right_space:2*x_len+right_space+mid_space])
ax3.annotate('i', xy=(-0.025, 1.0), xycoords="axes fraction", weight='bold')
n = 5
j = 1
soft = Analysis.Run(np.load('2011_Raw.npy'), np.load('2011_Prune_new_flat.npy'), Analysis.bval2011, np.load('2011bf_new_prune_flat_edit.npy')).prune_data
init_plot(soft[n])
i11[n].fits[1].plot_select('l','k',lw,-44,-35.2168)
i11[n].fits[1].plot_select('l','k',lw,-35.2168,-32.76,'--')

i11[n].fits[1].plot_select('r','r',lw,-44,-35.2168,'--')
i11[n].fits[1].plot_select('r','r',lw,-35.2168,-34.0052)

i11[n].fits[0].plot_select('l','r',lw,-34.0052,-29.6798)
i11[n].fits[0].plot_select('l','r',lw,-29.6798,-10,'--')

i11[n].fits[0].plot_select('r','#00ff00',lw,-34.0052,-29.6798,'--')
i11[n].fits[0].plot_select('r','#00ff00',lw,-29.6798,-10)

for k in se11[n]:
    ax3.axvline(k[0],color='k',lw=2)

set_axis(i11[n],-43.2812,-21.5518)
plt.xticks([-40,-30])

#PI--------------------------------------------

ax4 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax4.annotate('a', xy=(-0.05, 1.00), xycoords="axes fraction", weight='bold')
p[0]()

ax5 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax5.annotate('b', xy=(-0.05, 1.00), xycoords="axes fraction", weight='bold')
p[1]()

ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax6.annotate('c', xy=(-0.05, 1.00), xycoords="axes fraction", weight='bold')
p[6]()

#PI/4---------------------------------------------------

ax7 = plt.subplot(gs[:y_len,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax7.annotate('d', xy=(-0.05, 1.00), xycoords="axes fraction", weight='bold')
q[0]()

ax8 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax8.annotate('e', xy=(-0.05, 1.00), xycoords="axes fraction", weight='bold')
q[1]()

ax9 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+mid_space+right_space:2*x_len+right_space+mid_space])
ax9.annotate('f', xy=(-0.05, 1.00), xycoords="axes fraction", weight='bold')
q[3]()

ax1.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax1.yaxis.set_label_coords(-.05, 1.1)

ax3.set_xlabel('V$_{P}$ (mV)',size=12)

# %%
#Field Values
print('0',i14[0].b_val)
print('2',i14[2].b_val)
print('3',i14[3].b_val)
print('4',i14[4].b_val)
print('7',i14[7].b_val)
print('8',i14[8].b_val)
print('9',i14[9].b_val)
print('------------------')
print('5',i11[5].b_val)
print('8',i11[8].b_val)
# Out:
# ('0', 5.5845)
# ('2', 5.5835)
# ('3', 5.583)
# ('4', 5.5825)
# ('7', 5.581)
# ('8', 5.5805)
# ('9', 5.58)
# ------------------
# ('5', 5.5335)
# ('8', 5.532)

# %%
fig.savefig('Main Figure',dpi=1200)

# %%
plt.plot(d144[0],d144[1])

# %%
soft14[4].plot()
