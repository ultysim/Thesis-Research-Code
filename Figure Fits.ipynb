# %%
import numpy as np
from matplotlib.gridspec import GridSpec
import matplotlib as mpl
from matplotlib import pyplot as plt
fd = np.load('52figdata.npy')
ff = np.load('52figfits.npy')
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
def plotFig(data,fitbit):
    xa = fitbit
    freq = xa[0]
    amp = xa[1] 
    phasel = xa[2]
    phaser = xa[3]
    height = xa[4]
    slope = xa[5]
    posleft = min(data[0])
    posright = max(data[0]) 
    v0 = xa[11]     
    xpos = np.linspace(posleft,posright,10000)
    ytargl = height + amp*np.sin(freq*xpos + phasel) + slope*(xpos - v0)
    ytargr = height + amp*np.sin(freq*xpos + phaser) + slope*(xpos - v0)
    plt.plot(data[0],data[1])
    plt.plot(xpos,ytargl,'k',linewidth=2)
    plt.plot(xpos,ytargr,'r',linewidth=2)

# %%
def t(min,max):
    diff = max-min
    p = diff*.2
    return min-p,max+p

# %%
d = np.load('2014_Prune.npy')
bf = np.load('52bf.npy')
gs = GridSpec(1000,1000)

# %% [markdown]
# # Old Versions:

# %%
fig1 = plt.figure(figsize=[xin,yin])

ax2 = fig1.add_subplot(gs[:q,2*cpx+2*dx:999-dxl])
plt.tick_params(axis='y',which='both',labelleft='off',labelright='on')
plt.tick_params(axis='x',which='both',bottom='on',top='on',labelbottom='off')
plt.tick_params(axis='both', which='both', labelsize=ls)
ax3 = fig1.add_subplot(gs[q+sd:2*q+sd,2*cpx+2*dx:999-dxl])
plt.tick_params(axis='y',which='both',labelleft='off',labelright='on')
ax3.yaxis.set_label_position("right")
plt.tick_params(axis='x',which='both',bottom='on',top='on',labelbottom='off')
ax3.set_ylabel('$\Delta$R$_D$ (k$\Omega$)')
plt.tick_params(axis='both', which='both', labelsize=ls)
ax4 = fig1.add_subplot(gs[2*q+2*sd:3*q+2*sd,2*cpx+2*dx:999-dxl])
plt.tick_params(axis='y',which='both',labelleft='off',labelright='on')
ax4.set_xlabel('V$_P$(mV)',labelpad=0)
plt.tick_params(axis='both', which='both', labelsize=ls)
ax5 = fig1.add_subplot(gs[cpy+d:cpy+d+q,xd:cpx])
ax5.xaxis.labelpad = 0
ax5.set_ylabel('$\Delta$R$_D$ (k$\Omega$)',labelpad=1)
plt.tick_params(axis='both', which='both', labelsize=ls)
ax6 = fig1.add_subplot(gs[cpy+d:cpy+d+q,cpx+dx:2*cpx+dx])
plt.tick_params(axis='y',which='both',left='on',right='on',labelleft='off')
ax6.xaxis.labelpad = 0
ax6.set_xlabel('V$_P$(mV)')
plt.tick_params(axis='both', which='both', labelsize=ls)
ax7 = fig1.add_subplot(gs[cpy+d:cpy+d+q,2*cpx+2*dx:3*cpx+2*dx])
plt.tick_params(axis='y',which='both',left='on',right='on',labelleft='off')
ax7.xaxis.labelpad = 0
plt.tick_params(axis='both', which='both', labelsize=ls)

plt.sca(ax2)
ch.plotFig([fd[0][0],fd[1][0]],ff[0])
l,h = t(11.1938,11.7418)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.xticks([-18,-10])
plt.yticks([11.1938,11.4678,11.7418])
ax2.set_yticklabels([-0.5,0,0.5])
plt.sca(ax3)
ch.plotFig([fd[0][1],fd[1][1]],ff[1])
l,h = t(10.95,11.38)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.xticks([-18,-10])
plt.yticks([10.95,(10.95+11.38)/2,11.38])
ax3.set_yticklabels([-0.5,0,0.5])
plt.sca(ax4)
ch.plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.yticks([10.795,(10.795+11.153)/2,11.153])
plt.xticks([-18,-10])
ax4.set_yticklabels([-0.5,0,0.5])
plt.sca(ax5)
ch.plotFig([fd[0][3],fd[1][3]],ff[3])
l,h = t(11.3038,11.7463)
plt.xlim(-19.4314,-15.7676)
plt.ylim(l,h)
plt.xticks([-19,-17])
plt.yticks([11.3038,11.52505,11.7463])
ax5.set_yticklabels([-0.5,0,0.5])
plt.sca(ax6)
ch.plotFig([fd[0][4],fd[1][4]],ff[4])
l,h = t(11.0081,11.5387)
plt.xlim(-29.2258,-22.5901)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([11.0081,(11.0081+11.5387)/2,11.5387])
ax6.set_yticklabels([-0.5,0,0.5])
plt.sca(ax7)
ch.plotFig([fd[0][5],fd[1][5]],ff[5])
l,h = t(10.8916,11.4253)
plt.xlim(-28.5967,-22.448)
plt.xticks([-27,-24])
plt.ylim(l,h)
plt.yticks([10.8916,(10.8916+11.4253)/2,11.4253])
ax7.set_yticklabels([-0.5,0,0.5])
plt.savefig('Slip Fits_1',dpi=1200)

# %%
mpl.rcParams.update({'font.size': 8})
fig = plt.figure(figsize=[4.6,4.6*3/4])
right_space = 50
mid_space = 90
bot_space = 80
y_len = (1000-2*bot_space)/3
x_len = (1000-right_space-mid_space)/2

ax1 = fig.add_subplot(gs[:y_len,right_space:x_len+right_space])
plt.sca(ax1)
ch.plotFig([fd[0][0],fd[1][0]],ff[0])
l,h = t(11.1938,11.7418)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.xticks([-18,-10])
plt.yticks([11.1938,11.4678,11.7418])
ax1.set_yticklabels([11.2,11.5,11.7])
ax1.tick_params(axis='y',pad=2)

ax2 = fig.add_subplot(gs[:y_len,x_len+right_space+mid_space:])
plt.sca(ax2)
ch.plotFig([fd[0][3],fd[1][3]],ff[3])
l,h = t(11.3038,11.7463)
plt.xlim(-19.4314,-15.7676)
plt.ylim(l,h)
plt.xticks([-19,-17])
plt.yticks([11.3038,11.52505,11.7463])
ax2.set_yticklabels([11.3,11.5,11.7])
ax2.tick_params(axis='y',pad=2)

ax3 = fig.add_subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=10)
plt.sca(ax3)
plotFig([fd[0][1],fd[1][1]],ff[1])
l,h = t(10.95,11.38)
plt.xlim(-20.852,-7.933)
plt.ylim(l,h)
plt.xticks([-18,-10])
plt.yticks([10.95,11.165,11.38])
ax3.set_yticklabels([11.0,11.2,11.4])
ax3.tick_params(axis='y',pad=2)

ax4 = fig.add_subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])
plt.sca(ax4)
ch.plotFig([fd[0][4],fd[1][4]],ff[4])
l,h = t(11.0081,11.5387)
plt.xlim(-29.2258,-22.5901)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([11.0081,11.2734,11.5387])
ax4.set_yticklabels([11.0,11.3,11.5])
ax4.tick_params(axis='y',pad=2)

ax5 = fig.add_subplot(gs[2*y_len+2*bot_space:,right_space:x_len+right_space])
plt.sca(ax5)
ch.plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-17.363,-6.252)
plt.ylim(l,h)
plt.yticks([10.795,10.974,11.153])
plt.xticks([-18,-10])
ax5.set_yticklabels([10.8,11.0,11.2])
ax5.tick_params(axis='y',pad=2)

ax6 = fig.add_subplot(gs[2*y_len+2*bot_space:,x_len+right_space+mid_space:])
ax6.set_xlabel('V$_{P}$ (mV)',size=10)
ax6.xaxis.set_label_coords(-.115, -0.25)
plt.sca(ax6)
ch.plotFig([fd[0][5],fd[1][5]],ff[5])
l,h = t(10.8916,11.4253)
plt.xlim(-28.5967,-22.448)
plt.xticks([-27,-24])
plt.ylim(l,h)
plt.yticks([10.8916,11.15845,11.4253])
ax6.set_yticklabels([10.9,11.2,11.4])
ax6.tick_params(axis='y',pad=2)

# %%
plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-17.363,-6.252)
plt.ylim(l,h)
plt.yticks([10.795,10.974,11.153])
plt.xticks([-18,-10])
ax5.set_yticklabels([10.8,11.0,11.2])
ax5.tick_params(axis='y',pad=2)

# %%
plotFig(d[4],bf[4][0])
low = 10.958
high = 11.4439
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-22.47,-7.762)
plt.yticks([round(low,2),round(mid,2),round(high,2)])
plt.xticks([-18,-10])
# Out:
# ([<matplotlib.axis.XTick at 0x22fb70b8>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %%
plotFig(d[6],bf[6][0])
low = 10.9136
high = 11.3597
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-22.2413,-7.2891)
plt.yticks([round(low,2),round(mid,2),round(high,2)])
plt.xticks([-18,-10])
# Out:
# ([<matplotlib.axis.XTick at 0x2641a588>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %%
plotFig(d[7],bf[7][3])
low = 10.946
high = 11.2912
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-21.934,-15.5386)
plt.yticks([round(low,2),round(mid,2),round(high,2)])
plt.xticks([-21,-17])
ax5.tick_params(axis='y',pad=2)

# %%
mpl.rcParams.update({'font.size': 7})

fig = plt.figure(figsize=[4.6,4.6*3/2])

right_space = 50
mid_space = 95
bot_space = 35
y_len = (1000-4*bot_space)/5
x_len = (1000-right_space-mid_space)/2


ax1 = fig.add_subplot(gs[:y_len,right_space:x_len+right_space])

plotFig(d[4],bf[4][0])
low = 10.958
high = 11.4439
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-22.47,-7.762)
plt.yticks([round(low,1),round(high,1)])
plt.xticks([-18,-10])
plt.tick_params(axis='y',pad=2)



ax2 = fig.add_subplot(gs[:y_len,x_len+right_space+mid_space:])

plotFig([fd[0][3],fd[1][3]],ff[3])
l,h = t(11.3038,11.7463)
plt.xlim(-19.4314,-15.7676)
plt.ylim(l,h)
plt.xticks([-19,-17])
plt.yticks([11.3038,11.7463])
ax2.set_yticklabels([11.3,11.8])
ax2.tick_params(axis='y',pad=2)


ax3 = fig.add_subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])

plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-18.363,-6.252)
plt.ylim(l,h)
plt.yticks([10.795,11.153])
plt.xticks([-18,-10])
ax3.set_yticklabels([10.8,11.2])
ax3.tick_params(axis='y',pad=2)




ax4 = fig.add_subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])

plotFig([fd[0][4],fd[1][4]],ff[4])
l,h = t(11.0081,11.5387)
plt.xlim(-29.2258,-22.5901)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([11.0081,11.5387])
ax4.set_yticklabels([11.0,11.5])
ax4.tick_params(axis='y',pad=2)

ax5 = fig.add_subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax5.set_ylabel('R$_{D}$ (k$\Omega$)',size=10)

plotFig([fd[0][1],fd[1][1]],ff[1])
l,h = t(10.95,11.38)
plt.xlim(-20.852,-7.933)
plt.ylim(l,h)
plt.xticks([-18,-10])
plt.yticks([10.95,11.38])
ax5.set_yticklabels([11.0,11.4])
ax5.tick_params(axis='y',pad=2)

ax6 = fig.add_subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:])

plotFig(d[7],bf[7][3])
low = 10.946
high = 11.2912
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-21.934,-15.5386)
plt.yticks([low,high])
ax6.set_yticklabels([round(low,1),round(high,1)])
plt.xticks([-21,-17])
plt.tick_params(axis='y',pad=2)

ax7 = fig.add_subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:x_len+right_space])

plotFig(d[6],bf[6][0])
low = 10.9136
high = 11.3597
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-22.2413,-7.2891)
plt.yticks([low,high])
ax7.set_yticklabels([round(low,1),round(high,1)])
plt.xticks([-18,-10])
ax7.tick_params(axis='y',pad=2)

ax8 = fig.add_subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,x_len+right_space+mid_space:])

plotFig([fd[0][5],fd[1][5]],ff[5])
l,h = t(10.8916,11.4253)
plt.xlim(-28.5967,-22.448)
plt.xticks([-27,-24])
plt.ylim(l,h)
plt.yticks([10.8916,11.4253])
ax8.set_yticklabels([10.9,11.4])
ax8.tick_params(axis='y',pad=2)

ax9 = fig.add_subplot(gs[4*y_len+4*bot_space:,right_space:x_len+right_space])

plotFig([fd[0][0],fd[1][0]],ff[0])
l,h = t(11.1938,11.7418)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.xticks([-18,-10])
plt.yticks([11.1938,11.7418])
ax9.set_yticklabels([11.2,11.7])
ax9.tick_params(axis='y',pad=2)
plt.xlabel('V$_{P}$ (mV)',size=10)
ax9.xaxis.set_label_coords(1.15, -.15)

# %%
#Version 2

mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6*3/2])

right_space = 50
mid_space = 95
bot_space = 35
y_len = (1000-4*bot_space)/5
x_len = (1000-right_space-mid_space)/2


ax1 = fig.add_subplot(gs[:y_len,right_space:x_len+right_space])

plotFig(d[4],bf[4][0])
low = 10.958
high = 11.4439
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-22.47,-7.762)
plt.yticks([round(low,1),round(high,1)])
plt.xticks([-20,-10])
plt.tick_params(axis='y',pad=2)



ax2 = fig.add_subplot(gs[:y_len,x_len+right_space+mid_space:])

plotFig([fd[0][3],fd[1][3]],ff[3])
l,h = t(11.3038,11.7463)
plt.xlim(-19.4314,-15.7676)
plt.ylim(l,h)
plt.xticks([-19,-17])
plt.yticks([11.3038,11.7463])
ax2.set_yticklabels([11.3,11.8])
ax2.tick_params(axis='y',pad=2)


ax3 = fig.add_subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])

plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-18.363,-6.252)
plt.ylim(l,h)
plt.yticks([10.795,11.153])
plt.xticks([-15,-10])
ax3.set_yticklabels([10.8,11.2])
ax3.tick_params(axis='y',pad=2)




ax4 = fig.add_subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])

plotFig([fd[0][4],fd[1][4]],ff[4])
l,h = t(11.0081,11.5387)
plt.xlim(-29.2258,-22.5901)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([11.0081,11.5387])
ax4.set_yticklabels([11.0,11.5])
ax4.tick_params(axis='y',pad=2)

ax5 = fig.add_subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax5.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)

plotFig([fd[0][1],fd[1][1]],ff[1])
l,h = t(10.95,11.38)
plt.xlim(-20.852,-7.933)
plt.ylim(l,h)
plt.xticks([-20,-10])
plt.yticks([10.95,11.38])
ax5.set_yticklabels([11.0,11.4])
ax5.tick_params(axis='y',pad=2)

ax6 = fig.add_subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:])

plotFig(d[7],bf[7][3])
low = 10.946
high = 11.2912
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-21.934,-15.5386)
plt.yticks([low,high])
ax6.set_yticklabels([round(low,1),round(high,1)])
plt.xticks([-21,-17])
plt.tick_params(axis='y',pad=2)

ax7 = fig.add_subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:x_len+right_space])

plotFig(d[6],bf[6][0])
low = 10.9136
high = 11.3597
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-22.2413,-7.2891)
plt.yticks([low,high])
ax7.set_yticklabels([round(low,1),round(high,1)])
plt.xticks([-20,-10])
ax7.tick_params(axis='y',pad=2)

ax8 = fig.add_subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,x_len+right_space+mid_space:])

plotFig([fd[0][5],fd[1][5]],ff[5])
l,h = t(10.8916,11.4253)
plt.xlim(-28.5967,-22.448)
plt.xticks([-27,-24])
plt.ylim(l,h)
plt.yticks([10.8916,11.4253])
ax8.set_yticklabels([10.9,11.4])
ax8.tick_params(axis='y',pad=2)

ax9 = fig.add_subplot(gs[4*y_len+4*bot_space:,right_space:x_len+right_space])

plotFig([fd[0][0],fd[1][0]],ff[0])
l,h = t(11.1938,11.7418)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.xticks([-15,-10])
plt.yticks([11.1938,11.7418])
ax9.set_yticklabels([11.2,11.7])
ax9.tick_params(axis='y',pad=2)
plt.xlabel('V$_{P}$ (mV)',size=12)
ax9.xaxis.set_label_coords(1.15, -.20)

# %%
fig.savefig('2014 Best Fits V2',dpi=1200)

# %%
#Version 3

mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6])

right_space = 50
mid_space = 95
bot_space = 45
y_len = (1000-4*bot_space)/4
x_len = (1000-right_space-mid_space)/2


ax1 = fig.add_subplot(gs[:y_len,right_space:x_len+right_space])

plotFig(d[4],bf[4][0])
low = 10.958
high = 11.4439
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-22.47,-7.762)
plt.yticks([round(low,1),round(high,1)])
plt.xticks([-20,-10])
plt.tick_params(axis='y',pad=2)
plt.tick_params(axis='x',pad=3)



ax2 = fig.add_subplot(gs[:y_len,x_len+right_space+mid_space:])

plotFig([fd[0][3],fd[1][3]],ff[3])
l,h = t(11.3038,11.7463)
plt.xlim(-19.4314,-15.7676)
plt.ylim(l,h)
plt.xticks([-19,-17])
plt.yticks([11.3038,11.7463])
ax2.set_yticklabels([11.3,11.8])
ax2.tick_params(axis='y',pad=2)
plt.tick_params(axis='x',pad=3)

ax3 = fig.add_subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])

plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-18.363,-6.252)
plt.ylim(l,h)
plt.yticks([10.795,11.153])
plt.xticks([-15,-10])
ax3.set_yticklabels([10.8,11.2])
ax3.tick_params(axis='y',pad=2)
plt.tick_params(axis='x',pad=3)



ax4 = fig.add_subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])

plotFig([fd[0][4],fd[1][4]],ff[4])
l,h = t(11.0081,11.5387)
plt.xlim(-29.2258,-22.5901)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([11.0081,11.5387])
ax4.set_yticklabels([11.0,11.5])
ax4.tick_params(axis='y',pad=2)
plt.tick_params(axis='x',pad=3)

ax5 = fig.add_subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax5.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax5.yaxis.set_label_coords(-0.2, 1.1)

plotFig([fd[0][1],fd[1][1]],ff[1])
l,h = t(10.95,11.38)
plt.xlim(-20.852,-7.933)
plt.ylim(l,h)
plt.xticks([-20,-10])
plt.yticks([10.95,11.38])
ax5.set_yticklabels([11.0,11.4])
ax5.tick_params(axis='y',pad=2)
plt.tick_params(axis='x',pad=3)

ax6 = fig.add_subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:])

plotFig(d[7],bf[7][3])
low = 10.946
high = 11.2912
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-21.934,-15.5386)
plt.yticks([low,high])
ax6.set_yticklabels([round(low,1),round(high,1)])
plt.xticks([-21,-17])
plt.tick_params(axis='y',pad=2)
plt.tick_params(axis='x',pad=3)

ax7 = fig.add_subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:x_len+right_space])

plotFig(d[6],bf[6][0])
low = 10.9136
high = 11.3597
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-22.2413,-7.2891)
plt.yticks([low,high])
ax7.set_yticklabels([round(low,1),round(high,1)])
plt.xticks([-20,-10])
ax7.tick_params(axis='y',pad=2)
plt.tick_params(axis='x',pad=3)

ax8 = fig.add_subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,x_len+right_space+mid_space:])

plotFig([fd[0][5],fd[1][5]],ff[5])
l,h = t(10.8916,11.4253)
plt.xlim(-28.5967,-22.448)
plt.xticks([-27,-24])
plt.ylim(l,h)
plt.yticks([10.8916,11.4253])
ax8.set_yticklabels([10.9,11.4])
ax8.tick_params(axis='y',pad=2)
plt.xlabel('V$_{P}$ (mV)',size=12)
ax8.xaxis.set_label_coords(-0.11, -.20)
plt.tick_params(axis='x',pad=3)

'''
ax9 = fig.add_subplot(gs[4*y_len+4*bot_space:,right_space:x_len+right_space])

plotFig([fd[0][0],fd[1][0]],ff[0])
l,h = t(11.1938,11.7418)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.xticks([-15,-10])
plt.yticks([11.1938,11.7418])
ax9.set_yticklabels([11.2,11.7])
ax9.tick_params(axis='y',pad=2)
plt.xlabel('V$_{P}$ (mV)',size=12)
ax9.xaxis.set_label_coords(1.15, -.20)
'''
# Out:
# "\nax9 = fig.add_subplot(gs[4*y_len+4*bot_space:,right_space:x_len+right_space])\n\nplotFig([fd[0][0],fd[1][0]],ff[0])\nl,h = t(11.1938,11.7418)\nplt.xlim(-19.4,-8.5)\nplt.ylim(l,h)\nplt.xticks([-15,-10])\nplt.yticks([11.1938,11.7418])\nax9.set_yticklabels([11.2,11.7])\nax9.tick_params(axis='y',pad=2)\nplt.xlabel('V$_{P}$ (mV)',size=12)\nax9.xaxis.set_label_coords(1.15, -.20)\n"

# %%
fig.savefig('2014 Best Fits v3',dpi=1200)

# %%
#Version 4
def t(min,max):
    diff = max-min
    p = diff*.4
    return min-p,max+p


mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6])

right_space = 50
mid_space = 95
bot_space = 50
y_len = int((1000-4*bot_space)/4)
x_len = int((1000-right_space-mid_space)/2)


ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])

plotFig(d[4],bf[4][0])
low = 10.958
high = 11.4439
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-22.47,-7.762)
plt.yticks([round(low,1),round(high,1)])
plt.xticks([-20,-10])
plt.tick_params(axis='y',pad=1)
plt.tick_params(axis='x',pad=2)



ax2 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:])

plotFig([fd[0][4],fd[1][4]],ff[4])
l,h = t(11.0081,11.5387)
plt.xlim(-29.2258,-22.5901)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([11.0081,11.5387])
ax2.set_yticklabels([11.0,11.5])
plt.tick_params(axis='y',pad=1)
ax2.tick_params(axis='x',pad=2)

ax3 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])

ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax3.yaxis.set_label_coords(-0.25, -.15)

plotFig([fd[0][1],fd[1][1]],ff[1])
l,h = t(10.95,11.38)
plt.xlim(-20.852,-7.933)
plt.ylim(l,h)
plt.xticks([-20,-10])
plt.yticks([10.95,11.38])
ax3.set_yticklabels([11.0,11.4])
plt.tick_params(axis='y',pad=1)
ax3.tick_params(axis='x',pad=2)


ax4 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])

plotFig([fd[0][5],fd[1][5]],ff[5])
l,h = t(10.8916,11.4253)
plt.xlim(-28.5967,-22.448)
plt.xticks([-27,-23])
plt.ylim(l,h)
plt.yticks([10.8916,11.4253])
ax4.set_yticklabels([10.9,11.4])
plt.tick_params(axis='y',pad=1)
ax4.tick_params(axis='x',pad=2)

ax5 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])

plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-18.363,-6.252)
plt.ylim(l,h)
plt.yticks([10.795,11.153])
plt.xticks([-15,-10])
ax5.set_yticklabels([10.8,11.2])
plt.tick_params(axis='y',pad=1)
ax5.tick_params(axis='x',pad=2)

ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:])

temp = np.array(bf[7][3])
temp[2],temp[3] = temp[3],temp[2]

plotFig(d[7],temp)
low = 10.946
high = 11.2912
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-21.934,-15.5386)
plt.yticks([low,high])
ax6.set_yticklabels([round(low,1),round(high,1)])
plt.xticks([-21,-17])
plt.tick_params(axis='y',pad=1)
ax6.tick_params(axis='x',pad=2)

ax7 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:x_len+right_space])

plotFig([fd[0][0],fd[1][0]],ff[0])
l,h = t(11.1938,11.7418)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.xticks([-15,-10])
plt.yticks([11.1938,11.7418])
ax7.set_yticklabels([11.2,11.7])
plt.tick_params(axis='y',pad=1)
ax7.tick_params(axis='x',pad=2)
plt.xlabel('V$_{P}$ (mV)',size=12)
ax7.xaxis.set_label_coords(1.1, -.30)


ax8 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,x_len+right_space+mid_space:])

temp = np.array(ff[3])
#temp[2],temp[3] = temp[3],temp[2]

plotFig([fd[0][3],fd[1][3]],temp)
l,h = t(11.3038,11.7463)
plt.xlim(-19.4314,-15.7676)
plt.ylim(l,h)
plt.xticks([-19,-16])
plt.yticks([11.3038,11.7463])
ax8.set_yticklabels([11.3,11.8])
plt.tick_params(axis='y',pad=1)
ax8.tick_params(axis='x',pad=2)

# %%
#Version 5
def t(min,max):
    diff = max-min
    p = diff*.4
    return min-p,max+p


mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6*1.5])

right_space = 50
mid_space = 95
bot_space = 35
y_len = int((1000-4*bot_space)/4)
x_len = int((1000-right_space-mid_space)/2)
ypad = 2
xpad = 4

ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])

plotFig([fd[0][1],fd[1][1]],ff[1])
l,h = t(10.95,11.38)
plt.xlim(-20.852,-7.933)
plt.ylim(l,h)
plt.xticks([-20,-10])
plt.yticks([10.95,11.38],(11.0,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)






ax2 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:])

plotFig([fd[0][5],fd[1][5]],ff[5])
l,h = t(10.8916,11.4253)
plt.xlim(-28.5967,-22.448)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([10.8916,11.4253],(10.9,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)



ax3 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])

ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax3.yaxis.set_label_coords(-0.25, -.05)

plotFig(d[4],bf[4][0])
low = 10.958
high = 11.4439
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-22.47,-7.762)
plt.yticks([round(low,1),round(high,1)])
plt.xticks([-20,-10])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax4 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])

plotFig([fd[0][4],fd[1][4]],ff[4])
l,h = t(11.0081,11.5387)
plt.xlim(-29.2258,-22.5901)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([11.0081,11.5387],(11.0,11.5))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax5 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])

plotFig([fd[0][0],fd[1][0]],ff[0])
l,h = t(11.1938,11.7418)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.xticks([-15,-10])
plt.yticks([11.1938,11.7418],(11.2,11.7))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:])

temp = np.array(bf[7][3])
temp[2],temp[3] = temp[3],temp[2]

plotFig(d[7],temp)
low = 10.946
high = 11.2912
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-21.934,-15.5386)
plt.yticks([low,high],(round(low,1),round(high,1)))
plt.xticks([-21,-17])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

ax7 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:x_len+right_space])

plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-18.363,-6.252)
plt.ylim(l,h)
plt.yticks([10.795,11.153],(10.8,11.2))
plt.xticks([-15,-10])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


plt.xlabel('V$_{P}$ (mV)',size=12)
ax7.xaxis.set_label_coords(1.1, -.2)


ax8 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,x_len+right_space+mid_space:])

temp = np.array(ff[3])
temp[2],temp[3] = temp[3],temp[2]

plotFig([fd[0][3],fd[1][3]],temp)
l,h = t(11.3038,11.7463)
plt.xlim(-19.4314,-15.7676)
plt.ylim(l,h)
plt.xticks([-19,-16])
plt.yticks([11.3038,11.7463],(11.3,11.8))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

# %%
fig.savefig('2014 Slip Fits v5',dpi=1200)

# %%
#Version 6
def t(min,max):
    diff = max-min
    p = diff*.3
    return min-p,max+p


mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6*1.2])

right_space = 50
mid_space = 95
bot_space = 45
y_len = int((1000-4*bot_space)/4)
x_len = int((1000-right_space-mid_space)/2)
ypad = 2
xpad = 4

ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])

plotFig([fd[0][1],fd[1][1]],ff[1])
l,h = t(10.95,11.38)
plt.xlim(-20.852,-7.933)
plt.ylim(l,h)
plt.xticks([-20,-10])
plt.yticks([10.95,11.38],(11.0,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)






ax2 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:])

plotFig([fd[0][5],fd[1][5]],ff[5])
l,h = t(10.8916,11.4253)
plt.xlim(-28.5967,-22.448)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([10.8916,11.4253],(10.9,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)



ax3 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])

ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax3.yaxis.set_label_coords(-0.25, -.10)

plotFig(d[4],bf[4][0])
low = 10.958
high = 11.4439
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-22.47,-7.762)
plt.yticks([round(low,1),round(high,1)])
plt.xticks([-20,-10])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax4 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])

plotFig([fd[0][4],fd[1][4]],ff[4])
l,h = t(11.0081,11.5387)
plt.xlim(-29.2258,-22.5901)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([11.0081,11.5387],(11.0,11.5))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax5 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])

plotFig([fd[0][0],fd[1][0]],ff[0])
l,h = t(11.1938,11.7418)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.xticks([-15,-10])
plt.yticks([11.1938,11.7418],(11.2,11.7))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:])

temp = np.array(bf[7][3])
temp[2],temp[3] = temp[3],temp[2]

plotFig(d[7],temp)
low = 10.946
high = 11.2912
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-21.934,-15.5386)
plt.yticks([low,high],(round(low,1),round(high,1)))
plt.xticks([-21,-17])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

ax7 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:x_len+right_space])

plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-18.363,-6.252)
plt.ylim(l,h)
plt.yticks([10.795,11.153],(10.8,11.2))
plt.xticks([-15,-10])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


plt.xlabel('V$_{P}$ (mV)',size=12)
ax7.xaxis.set_label_coords(1.12, -.2)


ax8 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,x_len+right_space+mid_space:])

temp = np.array(ff[3])
temp[2],temp[3] = temp[3],temp[2]

plotFig([fd[0][3],fd[1][3]],temp)
l,h = t(11.3038,11.7463)
plt.xlim(-19.4314,-15.7676)
plt.ylim(l,h)
plt.xticks([-19,-16])
plt.yticks([11.3038,11.7463],(11.3,11.8))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

# %%
fig.savefig('2014 Slip Fits v6', dpi=1200)

# %%
#Version 7
def t(min,max):
    diff = max-min
    p = diff*.3
    return min-p,max+p


mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6*1.2])

right_space = 50
mid_space = 95
bot_space = 45
y_len = int((1000-4*bot_space)/4)
x_len = int((1000-right_space-mid_space)/2)
ypad = 2
xpad = 4

ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])

plotFig(d[4],bf[4][0])
low = 10.958
high = 11.4439
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-20.6,-7.762)
plt.yticks([round(low,1),round(high,1)])
plt.xticks([-20,-10])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax2 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:])

plotFig([fd[0][5],fd[1][5]],ff[5])
l,h = t(10.8916,11.4253)
plt.xlim(-28.5967,-22.448)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([10.8916,11.4253],(10.9,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)



ax3 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])

ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax3.yaxis.set_label_coords(-0.25, -.10)

plotFig([fd[0][1],fd[1][1]],ff[1])
l,h = t(10.95,11.38)
plt.xlim(-19.8,-7.2)
plt.ylim(l,h)
plt.xticks([-19,-10])
plt.yticks([10.95,11.38],(11.0,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax4 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])

plotFig([fd[0][4],fd[1][4]],ff[4])
l,h = t(11.0081,11.5387)
plt.xlim(-29.2258,-22.5901)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([11.0081,11.5387],(11.0,11.5))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax5 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])

plotFig([fd[0][0],fd[1][0]],ff[0])
l,h = t(11.1938,11.7418)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.xticks([-18,-10])
plt.yticks([11.1938,11.7418],(11.2,11.7))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:])

temp = np.array(bf[7][3])
temp[2],temp[3] = temp[3],temp[2]

plotFig(d[7],temp)
low = 10.946
high = 11.2912
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-21.934,-15.5386)
plt.yticks([low,high],(round(low,1),round(high,1)))
plt.xticks([-21,-17])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

ax7 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:x_len+right_space])

plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-18.363,-6.252)
plt.ylim(l,h)
plt.yticks([10.795,11.153],(10.8,11.2))
plt.xticks([-15,-10])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


plt.xlabel('V$_{P}$ (mV)',size=12)
ax7.xaxis.set_label_coords(1.12, -.2)


ax8 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,x_len+right_space+mid_space:])

temp = np.array(ff[3])
temp[2],temp[3] = temp[3],temp[2]

plotFig([fd[0][3],fd[1][3]],temp)
l,h = t(11.3038,11.7463)
plt.xlim(-19.4314,-15.7676)
plt.ylim(l,h)
plt.xticks([-19,-16])
plt.yticks([11.3038,11.7463],(11.3,11.8))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-12e3fbb61a62> in <module>()
#      87 ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:])
#      88
# ---> 89 temp = np.array(bf[7][3])
#      90 temp[2],temp[3] = temp[3],temp[2]
#      91
#
# IndexError: index 3 is out of bounds for axis 0 with size 2

# %%
fig.savefig('2014 Slip Fits v7', dpi=1200)

# %%
#Version 8-Pi/4
def t(min,max):
    diff = max-min
    p = diff*.3
    return min-p,max+p


mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6*1.2/2])

right_space = 50
mid_space = 95
bot_space = 70
y_len = int((1000-2*bot_space)/2)
x_len = int((1000-right_space-mid_space)/2)
ypad = 2
xpad = 2.5

ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])

temp = np.array(bf[7][3])
temp[2],temp[3] = temp[3],temp[2]

plotFig(d[7],temp)
low = 10.946
high = 11.2912
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-21.934,-15.5386)
plt.yticks([low,high],(round(low,1),round(high,1)))
plt.xticks([-21,-17])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax2 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:])

plotFig([fd[0][5],fd[1][5]],ff[5])
l,h = t(10.8916,11.4253)
plt.xlim(-28.5967,-22.448)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([10.8916,11.4253],(10.9,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax3 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])

ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax3.yaxis.set_label_coords(-0.25, 1.1)
plt.xlabel('V$_{P}$ (mV)',size=12)
ax3.xaxis.set_label_coords(1.12, -.2)

plotFig([fd[0][4],fd[1][4]],ff[4])
l,h = t(11.0081,11.5387)
plt.xlim(-29.2258,-22.5901)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([11.0081,11.5387],(11.0,11.5))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

ax4 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])

temp = np.array(ff[3])
temp[2],temp[3] = temp[3],temp[2]

plotFig([fd[0][3],fd[1][3]],temp)
l,h = t(11.3038,11.7463)
plt.xlim(-19.4314,-15.7676)
plt.ylim(l,h)
plt.xticks([-19,-16])
plt.yticks([11.3038,11.7463],(11.3,11.8))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

# %%
fig.savefig('2014 Slip Fits v8-Piby4', dpi=1200)

# %%
#Version 8-Pi
def t(min,max):
    diff = max-min
    p = diff*.3
    return min-p,max+p


mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6*1.2/2])

right_space = 50
mid_space = 95
bot_space = 70
y_len = int((1000-2*bot_space)/2)
x_len = int((1000-right_space-mid_space)/2)
ypad = 2
xpad = 2.5

ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])

plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-18.363,-6.252)
plt.ylim(l,h)
plt.yticks([10.795,11.153],(10.8,11.2))
plt.xticks([-15,-10])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax2 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:])

plotFig([fd[0][1],fd[1][1]],ff[1])
l,h = t(10.95,11.38)
plt.xlim(-19.8,-7.2)
plt.ylim(l,h)
plt.xticks([-19,-10])
plt.yticks([10.95,11.38],(11.0,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax3 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])

ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax3.yaxis.set_label_coords(-0.25, 1.1)

plt.xlabel('V$_{P}$ (mV)',size=12)
ax3.xaxis.set_label_coords(1.12, -.2)

plotFig(d[4],bf[4][0])
low = 10.958
high = 11.4439
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-20.6,-7.762)
plt.yticks([round(low,1),round(high,1)])
plt.xticks([-20,-10])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

ax4 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])

plotFig([fd[0][0],fd[1][0]],ff[0])
l,h = t(11.1938,11.7418)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.xticks([-18,-10])
plt.yticks([11.1938,11.7418],(11.2,11.7))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

# %%
fig.savefig('2014 Slip Fits v8-Pi', dpi=1200)

# %%
#Version 8-Pi-equal x axis
def t(min,max):
    diff = max-min
    p = diff*.3
    return min-p,max+p


mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6*1.1/2])

right_space = 50
mid_space = 95
bot_space = 40
y_len = int((1000-2*bot_space)/2)
x_len = int((1000-right_space-mid_space)/2)
ypad = 2
xpad = 2.5

ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])

plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-20.6,-6.252)
plt.ylim(l,h)
plt.yticks([10.795,11.153],(10.8,11.2))
plt.xticks([-17,-10],('',''))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax2 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:])

plotFig([fd[0][1],fd[1][1]],ff[1])
l,h = t(10.95,11.38)
plt.xlim(-20.6,-6.252)
plt.ylim(l,h)
plt.xticks([-17,-10],('',''))
plt.yticks([10.95,11.38],(11.0,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax3 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])

ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax3.yaxis.set_label_coords(-0.25, 1.1)

plt.xlabel('V$_{P}$ (mV)',size=12)
ax3.xaxis.set_label_coords(1.12, -.1)

plotFig(d[4],bf[4][0])
low = 10.958
high = 11.4439
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-20.6,-6.252)
plt.yticks([round(low,1),round(high,1)])
plt.xticks([-17,-10])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

ax4 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])

plotFig([fd[0][0],fd[1][0]],ff[0])
l,h = t(11.1938,11.7418)
plt.xlim(-20.6,-6.252)
plt.ylim(l,h)
plt.xticks([-17,-10])
plt.yticks([11.1938,11.7418],(11.2,11.7))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

# %%
fig.savefig('2014 Slip Fits v8-Pi-Full', dpi=1200)

# %%
import Analysis
run_2014 = Analysis.generate_2014()

# %%
#Version 9-Pi/4
def t(min,max):
    diff = max-min
    p = diff*.3
    return min-p,max+p


mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6*1.2/2])

right_space = 50
mid_space = 95
bot_space = 70
y_len = int((1000-2*bot_space)/2)
x_len = int((1000-right_space-mid_space)/2)
ypad = 2
xpad = 2.5

ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])

temp = np.array(bf[7][3])
temp[2],temp[3] = temp[3],temp[2]

run_2014.prune_data[7].plot_fit(3)
low = 10.946
high = 11.2912
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-26,-19.86)
plt.yticks([low,high],(round(low,1),round(high,1)))
plt.xticks([-25,-21])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax2 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:])

plotFig([fd[0][5],fd[1][5]],ff[5])
l,h = t(10.8916,11.4253)
plt.xlim(-28.5967,-22.448)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([10.8916,11.4253],(10.9,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax3 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])

ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax3.yaxis.set_label_coords(-0.25, 1.1)
plt.xlabel('V$_{P}$ (mV)',size=12)
ax3.xaxis.set_label_coords(1.12, -.2)

plotFig([fd[0][4],fd[1][4]],ff[4])
l,h = t(11.0081,11.5387)
plt.xlim(-29.2258,-22.5901)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([11.0081,11.5387],(11.0,11.5))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

ax4 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])

temp = np.array(ff[3])
temp[2],temp[3] = temp[3],temp[2]

plotFig([fd[0][3],fd[1][3]],temp)
l,h = t(11.3038,11.7463)
plt.xlim(-19.4314,-15.7676)
plt.ylim(l,h)
plt.xticks([-19,-16])
plt.yticks([11.3038,11.7463],(11.3,11.8))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

plt.tick_params(axis='x',pad=xpad)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-802161da5a24> in <module>()
#      20 ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
#      21
# ---> 22 temp = np.array(bf[7][3])
#      23 temp[2],temp[3] = temp[3],temp[2]
#      24
#
# IndexError: index 3 is out of bounds for axis 0 with size 2

# %%
fig.savefig('2014 Slip Fits v9-Piby4', dpi=1200)

# %% [markdown]
# # Current Work:

# %%
#Version 8 - 7 plus letters
def t(min,max):
    diff = max-min
    p = diff*.3
    return min-p,max+p


mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6*1.2])

right_space = 50
mid_space = 95
bot_space = 45
y_len = int((1000-4*bot_space)/4)
x_len = int((1000-right_space-mid_space)/2)
ypad = 2
xpad = 4

ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])

plotFig(d[4],bf[4][0])
low = 10.958
high = 11.4439
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-20.6,-7.762)
plt.yticks([round(low,1),round(high,1)])
plt.xticks([-20,-10])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax2 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:])

plotFig([fd[0][5],fd[1][5]],ff[5])
l,h = t(10.8916,11.4253)
plt.xlim(-28.5967,-22.448)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([10.8916,11.4253],(10.9,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)



ax3 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])

ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax3.yaxis.set_label_coords(-0.25, -.10)

plotFig([fd[0][1],fd[1][1]],ff[1])
l,h = t(10.95,11.38)
plt.xlim(-19.8,-7.2)
plt.ylim(l,h)
plt.xticks([-19,-10])
plt.yticks([10.95,11.38],(11.0,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax4 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])

plotFig([fd[0][4],fd[1][4]],ff[4])
l,h = t(11.0081,11.5387)
plt.xlim(-29.2258,-22.5901)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([11.0081,11.5387],(11.0,11.5))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax5 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])

plotFig([fd[0][0],fd[1][0]],ff[0])
l,h = t(11.1938,11.7418)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.xticks([-18,-10])
plt.yticks([11.1938,11.7418],(11.2,11.7))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:])

temp = np.array(bf[7][1])
temp[2],temp[3] = temp[3],temp[2]

plotFig(d[7],temp)
low = 10.91
high = 11.35
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-28.46,-20)
plt.yticks([low,high],(round(low,1),round(high,1)))
plt.xticks([-27,-22])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

ax7 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:x_len+right_space])

plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-18.363,-6.252)
plt.ylim(l,h)
plt.yticks([10.795,11.153],(10.8,11.2))
plt.xticks([-15,-10])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


plt.xlabel('V$_{P}$ (mV)',size=12)
ax7.xaxis.set_label_coords(1.12, -.2)


ax8 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,x_len+right_space+mid_space:])

temp = np.array(ff[3])
temp[2],temp[3] = temp[3],temp[2]

plotFig([fd[0][3],fd[1][3]],temp)
l,h = t(11.3038,11.7463)
plt.xlim(-19.4314,-15.7676)
plt.ylim(l,h)
plt.xticks([-19,-16])
plt.yticks([11.3038,11.7463],(11.3,11.8))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

# %%
temp = np.array(bf[7][1])
temp[2],temp[3] = temp[3],temp[2]

plotFig(d[7],temp)

# %%
import Analysis
bf_new = np.load('2014bf_new_residual.npy')
data = Analysis.Run(np.load('2014_Raw.npy'), np.load('2014_Prune.npy'), Analysis.bval2014, np.load('2014bf_new_residual.npy'))

# %%
for i in range(len(data.prune_data)):
    if len(bf_new[i]) > 0:
        for j in range(len(bf_new[i])):
            plt.figure()
            plotFig([data.prune_data[i].x,data.prune_data[i].y],bf_new[i][j])
            plt.title(str(i)+', '+str(j))

# %% [markdown]
# # New Figure:

# %%
#Version 10 - old res plus letters
def t(min,max):
    diff = max-min
    p = diff*.3
    return min-p,max+p


mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6*1.2])

right_space = 50
mid_space = 95
bot_space = 45
y_len = int((1000-4*bot_space)/4)
x_len = int((1000-right_space-mid_space)/2)
ypad = 2
xpad = 4

ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax1.annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")

plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-18.363,-6.252)
plt.ylim(l,h)
plt.yticks([10.795,11.153],(10.8,11.2))
plt.xticks([-17,-8])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

ax2 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:])
ax2.annotate('E', xy=(0.01, 0.88), xycoords="axes fraction")

temp = np.array(bf[7][1])
temp[2],temp[3] = temp[3],temp[2]

plotFig(d[7],temp)
low = 10.91
high = 11.35
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-28.46,-20)
plt.yticks([low,high],(round(low,1),round(high,1)))
plt.xticks([-27,-22])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)



ax3 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax3.annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax3.yaxis.set_label_coords(-0.25, -.10)

plotFig([fd[0][1],fd[1][1]],ff[1])
l,h = t(10.95,11.38)
plt.xlim(-19.8,-7.2)
plt.ylim(l,h)
plt.xticks([-19,-10])
plt.yticks([10.95,11.38],(11.0,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax4 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])
ax4.annotate('F', xy=(0.01, 0.88), xycoords="axes fraction")

plotFig([fd[0][5],fd[1][5]],ff[5])
l,h = t(10.8916,11.4253)
plt.xlim(-28.5967,-22.448)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([10.8916,11.4253],(10.9,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax5 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax5.annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")

plotFig(d[4],bf[4][0])
low = 10.958
high = 11.4439
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-20.6,-7.762)
plt.yticks([round(low,1),round(high,1)])
plt.xticks([-19,-10])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:])
ax6.annotate('G', xy=(0.01, 0.88), xycoords="axes fraction")

plotFig([fd[0][4],fd[1][4]],ff[4])
l,h = t(11.0081,11.5387)
plt.xlim(-29.2258,-22.5901)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([11.0081,11.5387],(11.0,11.5))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax7 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:x_len+right_space])
ax7.annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")

plotFig([fd[0][0],fd[1][0]],ff[0])
l,h = t(11.1938,11.7418)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.xticks([-18,-10])
plt.yticks([11.1938,11.7418],(11.2,11.7))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


plt.xlabel('V$_{P}$ (mV)',size=12)
ax7.xaxis.set_label_coords(1.12, -.2)


ax8 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,x_len+right_space+mid_space:])
ax8.annotate('H', xy=(0.01, 0.88), xycoords="axes fraction")

temp = np.array(ff[3])
temp[2],temp[3] = temp[3],temp[2]

plotFig([fd[0][3],fd[1][3]],temp)
l,h = t(11.3038,11.7463)
plt.xlim(-19.4314,-15.7676)
plt.ylim(l,h)
plt.xticks([-19,-16])
plt.yticks([11.3038,11.7463],(11.3,11.8))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

# %%
fig.savefig('2014 Best Fits V10-1',dpi=1200)

# %%
import Analysis
data = Analysis.Run(np.load('2014_Raw.npy'), np.load('2014_Prune.npy'), Analysis.bval2014, np.load('2014bf_new_residual.npy'))

# %%
#Version 10 - old res plus letters
def t(min,max):
    diff = max-min
    p = diff*.3
    return min-p,max+p


mpl.rcParams.update({'font.size': 8})

fig = plt.figure(figsize=[4.6,4.6*1.2])

right_space = 50
mid_space = 95
bot_space = 45
y_len = int((1000-4*bot_space)/4)
x_len = int((1000-right_space-mid_space)/2)
ypad = 2
xpad = 4

ax1 = plt.subplot(gs[:y_len,right_space:x_len+right_space])
ax1.annotate('A', xy=(0.01, 0.88), xycoords="axes fraction")

plotFig([fd[0][2],fd[1][2]],ff[2])
l,h = t(10.795,11.153)
plt.xlim(-18.363,-6.252)
plt.ylim(l,h)
plt.yticks([10.795,11.153],(10.8,11.2))
plt.xticks([-17,-8])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

ax2 = plt.subplot(gs[:y_len,x_len+right_space+mid_space:])
ax2.annotate('E', xy=(0.01, 0.88), xycoords="axes fraction")

temp = np.array(bf[7][1])
temp[2],temp[3] = temp[3],temp[2]

plotFig(d[7],temp)
low = 10.91
high = 11.35
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-28.46,-20)
plt.yticks([low,high],(round(low,1),round(high,1)))
plt.xticks([-27,-22])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)



ax3 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,right_space:x_len+right_space])
ax3.annotate('B', xy=(0.01, 0.88), xycoords="axes fraction")
ax3.set_ylabel('R$_{D}$ (k$\Omega$)',size=12)
ax3.yaxis.set_label_coords(-0.25, -.10)

data.prune_data[7].plot_fit(0)
l,h = t(10.95,11.3)
plt.xlim(-18.863,-10.539)
plt.ylim(l,h)
plt.xticks([-18,-12])
plt.yticks([10.95,11.3],(11.0,11.3))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax4 = plt.subplot(gs[y_len+bot_space:2*y_len+bot_space,x_len+right_space+mid_space:])
ax4.annotate('F', xy=(0.01, 0.88), xycoords="axes fraction")

plotFig([fd[0][5],fd[1][5]],ff[5])
l,h = t(10.8916,11.4253)
plt.xlim(-28.5967,-22.448)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([10.8916,11.4253],(10.9,11.4))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax5 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,right_space:x_len+right_space])
ax5.annotate('C', xy=(0.01, 0.88), xycoords="axes fraction")

plotFig(d[4],bf[4][0])
low = 10.958
high = 11.4439
mid = (low+high)/2.0
l,h = t(low,high)
plt.ylim(l,h)
plt.xlim(-20.6,-7.762)
plt.yticks([round(low,1),round(high,1)])
plt.xticks([-19,-10])
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax6 = plt.subplot(gs[2*y_len+2*bot_space:3*y_len+2*bot_space,x_len+right_space+mid_space:])
ax6.annotate('G', xy=(0.01, 0.88), xycoords="axes fraction")

plotFig([fd[0][4],fd[1][4]],ff[4])
l,h = t(11.0081,11.5387)
plt.xlim(-29.2258,-22.5901)
plt.xticks([-28,-24])
plt.ylim(l,h)
plt.yticks([11.0081,11.5387],(11.0,11.5))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


ax7 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,right_space:x_len+right_space])
ax7.annotate('D', xy=(0.01, 0.88), xycoords="axes fraction")

data.prune_data[0].plot_fit(0)
l,h = t(11.1938,11.7418)
plt.xlim(-19.4,-8.5)
plt.ylim(l,h)
plt.xticks([-18,-10])
plt.yticks([11.1938,11.7418],(11.2,11.7))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)


plt.xlabel('V$_{P}$ (mV)',size=12)
ax7.xaxis.set_label_coords(1.12, -.2)


ax8 = plt.subplot(gs[3*y_len+3*bot_space:4*y_len+3*bot_space,x_len+right_space+mid_space:])
ax8.annotate('H', xy=(0.01, 0.88), xycoords="axes fraction")

temp = np.array(ff[3])
temp[2],temp[3] = temp[3],temp[2]

plotFig([fd[0][3],fd[1][3]],temp)
l,h = t(11.3038,11.7463)
plt.xlim(-19.4314,-15.7676)
plt.ylim(l,h)
plt.xticks([-19,-16])
plt.yticks([11.3038,11.7463],(11.3,11.8))
plt.tick_params(axis='y',pad=ypad)
plt.tick_params(axis='x',pad=xpad)

# %%
fig.savefig('2014 Best Fits V10-2',dpi=1200)
